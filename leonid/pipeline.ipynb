# %% [markdown]
# # Modules and settings

# %%
import os
import pandas as pd
import numpy as np
import gc
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
try:
    import cPickle as pickle
except:
    import pickle
import time

# %%
DATA_PATH = '../input/'
PRED_TEST_PATH = '../submit/'
PRED_TRAIN_PATH = '../submit/'
FOLDS_PATH = '../kvr777/folds/'
FEATURES_PATH = '../features/'
MODEL_NAME = 'leonid07'

# %%
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %%
def convert_col_to_proper_int(df_col):
    col_type = df_col.dtype
    c_min = df_col.min()
    c_max = df_col.max()
#     print('convert_col_to_proper_int column: ', df_col.name, 'type: ', col_type, 'c_min: ', c_min)
    if ((str(col_type)[:3] == 'int') | (str(col_type)[:4] == 'uint')): # | (str(col_type)[:5] == 'float')
        if c_min < 0:
#             print('c_min: ', c_min, 'less 0')
            if c_min >= np.iinfo(np.int8).min and c_max <= np.iinfo(np.int8).max:
                df_col = df_col.astype(np.int8)
            elif c_min >= np.iinfo(np.int16).min and c_max <= np.iinfo(np.int16).max:
                df_col = df_col.astype(np.int16)
            elif c_min >= np.iinfo(np.int32).min and c_max <= np.iinfo(np.int32).max:
                df_col = df_col.astype(np.int32)
            elif c_min >= np.iinfo(np.int64).min and c_max <= np.iinfo(np.int64).max:
                df_col = df_col.astype(np.int64)
        else:
#             print('c_min: ', c_min, 'not less 0')
            if c_max <= np.iinfo(np.uint8).max:
                df_col = df_col.astype(np.uint8)
            elif c_max <= np.iinfo(np.uint16).max:
                df_col = df_col.astype(np.uint16)
            elif c_max <= np.iinfo(np.uint32).max:
                df_col = df_col.astype(np.uint32)
            elif c_max <= np.iinfo(np.uint64).max:
                df_col = df_col.astype(np.uint64)
            
    return df_col

def convert_col_to_proper_float(df_col):
    col_type = df_col.dtype
    if str(col_type)[:5] == 'float':
        unique_count = len(np.unique(df_col))
        df_col_temp = df_col.astype(np.float32)
        if len(np.unique(df_col_temp)) == unique_count:
            df_col = df_col_temp
            c_min = df_col.min()
            c_max = df_col.max()
            if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                df_col_temp = df_col.astype(np.float16)
                if len(np.unique(df_col_temp)) == unique_count:
                    df_col = df_col_temp
            
    return df_col



def float_to_int(df):
    """ iterate through all float columns of a dataframe and modify the data type
        to reduce memory usage.
    """
#     print('Begin float_to_int')
    for col in df.columns:
        col_type = df[col].dtype
#         print('column: ', col, 'type: ', col_type)
        if str(col_type)[:5] == 'float':
            if (df[col] % 1 == 0).all():
                df[col] = convert_col_to_proper_int(df[col].astype(np.int64))
    
    return df

def float_reduced(df):
    """ iterate through all float columns of a dataframe and modify the data type
        to reduce memory usage.
    """
#     print('Begin float_reduced')
    for col in df.columns:
        col_type = df[col].dtype
#         print('column: ', col, 'type: ', col_type)
        if str(col_type)[:5] == 'float':
            df[col] = convert_col_to_proper_float(df[col])
    
    return df

def int_reduced(df):
    """ iterate through all int columns of a dataframe and modify the data type
        to reduce memory usage.
    """
#     print('Begin float_reduced')
    for col in df.columns:
        df[col] = convert_col_to_proper_int(df[col])
    
    return df

# %% [markdown]
# # Load data

# %%
# %%time
# Loading from pickle example
crowded_features_data_store = f'{FEATURES_PATH}crowded_features_data_store.pkl'
if os.path.isfile(crowded_features_data_store):
    print("loading data from pickle file", crowded_features_data_store)
    with open(os.path.abspath(crowded_features_data_store), 'rb') as f:
        crowded_features_df, _, _, _ = pickle.load(f, encoding='bytes')
        print('crowded_features_df:', type(crowded_features_df), crowded_features_df.shape)
#         print('target:', type(target), target.shape)
#         print('train_idx_rng:', type(train_idx_rng), 'start:', train_idx_rng.start,
#               'stop:', train_idx_rng.stop, 'step:', train_idx_rng.step)
#         print('test_idx_rng:', type(test_idx_rng), 'start:', test_idx_rng.start,
#               'stop:', test_idx_rng.stop, 'step:', test_idx_rng.step)

izmajlovkonstantin3_original_data_store = f'{FEATURES_PATH}izmajlovkonstantin3_original_data_store.pkl'
if os.path.isfile(izmajlovkonstantin3_original_data_store):
    print("loading data from pickle file", izmajlovkonstantin3_original_data_store)
    with open(os.path.abspath(izmajlovkonstantin3_original_data_store), 'rb') as f:
        total_df, target, train_idx_rng, test_idx_rng = pickle.load(f, encoding='bytes')
        print('total_df:', type(total_df), total_df.shape)
        print('target:', type(target), target.shape)
        print('train_idx_rng:', type(train_idx_rng), 'start:', train_idx_rng.start,
              'stop:', train_idx_rng.stop, 'step:', train_idx_rng.step)
        print('test_idx_rng:', type(test_idx_rng), 'start:', test_idx_rng.start,
              'stop:', test_idx_rng.stop, 'step:', test_idx_rng.step)
# Out:
# loading data from pickle file ../features/crowded_features_data_store.pkl
# crowded_features_df: <class 'pandas.core.frame.DataFrame'> (53801, 5369)
# loading data from pickle file ../features/izmajlovkonstantin3_original_data_store.pkl
# total_df: <class 'pandas.core.frame.DataFrame'> (53801, 5495)
# target: <class 'numpy.ndarray'> (4459,)
# train_idx_rng: <class 'range'> start: 0 stop: 4459 step: 1
# test_idx_rng: <class 'range'> start: 4459 stop: 53801 step: 1
# Wall time: 3.58 s

# %%
# %%time
total_df=int_reduced(float_reduced(float_to_int(total_df)))
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53801 entries, 0 to 53800
# Columns: 5495 entries, 48df886f9 to 66ace2992/b791ce9aa
# dtypes: float32(4814), float64(680), int32(1)
# memory usage: 1.2 GB
# Wall time: 1h 1min 15s

# %%
len(set(crowded_features_df.columns)-set(total_df.columns))
# Out:
# 2670

# %%
len(set(total_df.columns)-set(crowded_features_df.columns))
# Out:
# 2796

# %%
# %%time
total_df = total_df.join(crowded_features_df.reset_index(drop=True),
              lsuffix='_izmajlov', rsuffix='_crowded', how='outer').fillna(0)#, inplace=True
# total_df.merge(crowded_features_df.reset_index(drop=True),
#               suffixes=('_izmajlov', '_crowded'), how='outer').fillna(0, inplace=True)
# total_df = pd.concat([total_df, crowded_features_df[list(len(set(total_df.columns)-set(crowded_features_df.columns)))],
#                          clustering_features,
#                          gp_clustering_ii], axis=1, verify_integrity=True).fillna(0)
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53801 entries, 0 to 53800
# Columns: 10864 entries, 48df886f9 to gp_clustering_ii_275
# dtypes: float16(6), float32(7267), float64(1463), int32(1), uint16(4), uint8(2123)
# memory usage: 2.2 GB
# Wall time: 9.09 s

# %%
# %%time
X = total_df.iloc[train_idx_rng]
test = total_df.iloc[test_idx_rng]
# Out:
# Wall time: 1.68 s

# %%
X.shape, test.shape
# Out:
# ((4459, 10864), (49342, 10864))

# %%
# %%time
# y = np.log1p(target.target)
y = np.log1p(target)
# y.reshape(1,-1)
y.shape
# Out:
# Wall time: 0 ns

# %%
# %%time
from boostaroota import BoostARoota
br = BoostARoota(metric='rmse', iters = 20)
br.fit(X, y)
# Out:
# Round:  1  iteration:  1
# Round:  1  iteration:  2
# Round:  1  iteration:  3
# Round:  1  iteration:  4
# Round:  1  iteration:  5
# Round:  1  iteration:  6
# Round:  1  iteration:  7
# Round:  1  iteration:  8
# Round:  1  iteration:  9
# Round:  1  iteration:  10
# Round:  1  iteration:  11
# Round:  1  iteration:  12
# Round:  1  iteration:  13
# Round:  1  iteration:  14
# Round:  1  iteration:  15
# Round:  1  iteration:  16
# Round:  1  iteration:  17
# Round:  1  iteration:  18
# Round:  1  iteration:  19
# Round:  1  iteration:  20
# Round:  2  iteration:  1
# Round:  2  iteration:  2
# Round:  2  iteration:  3
# Round:  2  iteration:  4
# Round:  2  iteration:  5
# Round:  2  iteration:  6
# Round:  2  iteration:  7
# Round:  2  iteration:  8
# Round:  2  iteration:  9
# Round:  2  iteration:  10
# Round:  2  iteration:  11
# Round:  2  iteration:  12
# Round:  2  iteration:  13
# Round:  2  iteration:  14
# Round:  2  iteration:  15
# Round:  2  iteration:  16
# Round:  2  iteration:  17
# Round:  2  iteration:  18
# Round:  2  iteration:  19
# Round:  2  iteration:  20
# Round:  3  iteration:  1
# Round:  3  iteration:  2
# Round:  3  iteration:  3
# Round:  3  iteration:  4
# Round:  3  iteration:  5
# Round:  3  iteration:  6
# Round:  3  iteration:  7
# Round:  3  iteration:  8
# Round:  3  iteration:  9
# Round:  3  iteration:  10
# Round:  3  iteration:  11
# Round:  3  iteration:  12
# Round:  3  iteration:  13
# Round:  3  iteration:  14
# Round:  3  iteration:  15
# Round:  3  iteration:  16
# Round:  3  iteration:  17
# Round:  3  iteration:  18
# Round:  3  iteration:  19
# Round:  3  iteration:  20
# Round:  4  iteration:  1
# Round:  4  iteration:  2
# Round:  4  iteration:  3
# Round:  4  iteration:  4
# Round:  4  iteration:  5
# Round:  4  iteration:  6
# Round:  4  iteration:  7
# Round:  4  iteration:  8
# Round:  4  iteration:  9
# Round:  4  iteration:  10
# Round:  4  iteration:  11
# Round:  4  iteration:  12
# Round:  4  iteration:  13
# Round:  4  iteration:  14
# Round:  4  iteration:  15
# Round:  4  iteration:  16
# Round:  4  iteration:  17
# Round:  4  iteration:  18
# Round:  4  iteration:  19
# Round:  4  iteration:  20
# BoostARoota ran successfully! Algorithm went through  4  rounds.
# Wall time: 11min 21s

# %%
remaining_vars = list(br.keep_vars_)
print(len(remaining_vars))
# Out:
# 784

# %%
remaining_vars
# Out:
# ['48df886f9',
#  '34b15f335',
#  '30347e683',
#  '6ee66e115',
#  '20aa07010_izmajlov',
#  'dc5a8f1d8_izmajlov',
#  '11d86fa6a_izmajlov',
#  '4681de4fd_izmajlov',
#  'adf119b9a_izmajlov',
#  'cff75dd09',
#  'b8a716ebf_izmajlov',
#  '6c7a4567c',
#  '4fcfd2b4d',
#  'f3b9c0b95',
#  'd966ac62c',
#  '68b647452_izmajlov',
#  '0d866c3d7_izmajlov',
#  'bd8f989f1_izmajlov',
#  '22ed6dba3_izmajlov',
#  '92b13ebba_izmajlov',
#  '233c7c17c_izmajlov',
#  '2cb4d123e_izmajlov',
#  '87ffda550_izmajlov',
#  '822e49b95_izmajlov',
#  'd04e16aed_izmajlov',
#  'ec863cb52',
#  'ea18d720e_izmajlov',
#  '408d86ce9_izmajlov',
#  'ecdef52b2_izmajlov',
#  '2d6bd8275_izmajlov',
#  'dfdf4b580_izmajlov',
#  'feed9d437_izmajlov',
#  '645b47cde_izmajlov',
#  '7298ca1ef_izmajlov',
#  '8c94b6675_izmajlov',
#  'e421c414e',
#  '0656586a4_izmajlov',
#  '0b8e10df6_izmajlov',
#  'f115e74c0_izmajlov',
#  '54b1c1bc0_izmajlov',
#  'bd550871c_izmajlov',
#  '21e0e6ae3_izmajlov',
#  '64534cc93_izmajlov',
#  '0f8d7b98e_izmajlov',
#  '251d1aa17_izmajlov',
#  '0a69cc2be_izmajlov',
#  '963a49cdc_izmajlov',
#  '587a5d8c3_izmajlov',
#  '1e8801477_izmajlov',
#  '8e7a80f64',
#  '7207afb67',
#  '4b6c549b1_izmajlov',
#  'a75d400b8_izmajlov',
#  '35da68abb_izmajlov',
#  '68a945b18_izmajlov',
#  '526ed2bec_izmajlov',
#  '87ba106d3',
#  '63c094ba4_izmajlov',
#  'b1b17b543',
#  '14a5969a6_izmajlov',
#  '342e7eb03_izmajlov',
#  '4c60b70b8_izmajlov',
#  'a1995906f_izmajlov',
#  '4da206d28_izmajlov',
#  'c1b9f4e76_izmajlov',
#  '0ce078942',
#  'b30e932ba_izmajlov',
#  '29c059dd2_izmajlov',
#  '2761e2b76_izmajlov',
#  '935ca66a9_izmajlov',
#  '5547d6e11_izmajlov',
#  '2b85882ad_izmajlov',
#  'a6e871369_izmajlov',
#  '6d2ece683_izmajlov',
#  'ba136ae3f_izmajlov',
#  '794e93ca6_izmajlov',
#  '7623d805a_izmajlov',
#  '632586103_izmajlov',
#  'e078302ef_izmajlov',
#  'f72edfb37_izmajlov',
#  '8f3740670_izmajlov',
#  '1184df5c2_izmajlov',
#  '041c5d0c9_izmajlov',
#  '861076e21_izmajlov',
#  'dbfa2b77f_izmajlov',
#  'e8b513e29_izmajlov',
#  'ce8ce671e_izmajlov',
#  '6c0e0801a_izmajlov',
#  '26fc93eb7_izmajlov',
#  '0572565c2_izmajlov',
#  '20442bac4_izmajlov',
#  '66ace2992_izmajlov',
#  'fb49e4212_izmajlov',
#  '6619d81fc_izmajlov',
#  '7950f4c11',
#  '89ca53693_izmajlov',
#  'bdf773176_izmajlov',
#  '9df4daa99_izmajlov',
#  '8337d1adc_izmajlov',
#  'aca228668_izmajlov',
#  '5747a79a9_izmajlov',
#  '6eef030c1_izmajlov',
#  '2b2a10857_izmajlov',
#  'fc99f9426_izmajlov',
#  '83c3779bf_izmajlov',
#  'c624e6627_izmajlov',
#  '070f95c99_izmajlov',
#  'e222309b0_izmajlov',
#  '6f88afe65_izmajlov',
#  'e13b0c0aa_izmajlov',
#  '17b81a716_izmajlov',
#  'bb1113dbb_izmajlov',
#  'bd6da0cca_izmajlov',
#  'b6fa5a5fd_izmajlov',
#  '956d228b9_izmajlov',
#  '6dad99586',
#  'df838756c_izmajlov',
#  '8ceddccb8',
#  '88c0ec0a6_izmajlov',
#  '36a56d23e_izmajlov',
#  '600a08d97',
#  '6cf7866c1_izmajlov',
#  'd251ee3b4_izmajlov',
#  'ce3d7595b_izmajlov',
#  '2b8851e90_izmajlov',
#  '480e78cb0_izmajlov',
#  'b43a7cfd5_izmajlov',
#  '94e568b42',
#  '024c577b9_izmajlov',
#  '5b943716b_izmajlov',
#  '53a550111_izmajlov',
#  '51d4053c7_izmajlov',
#  '0a953f97e_izmajlov',
#  '2ec5b290f_izmajlov',
#  '32b64ff51',
#  '0106dd950',
#  '32174174c_izmajlov',
#  '2155f5e16_izmajlov',
#  '05f54f417_izmajlov',
#  '5a1589f1a_izmajlov',
#  '9f2f1099b_izmajlov',
#  '9e3aea49a_izmajlov',
#  'cd24eae8a_izmajlov',
#  '788e6045c',
#  '89cebceab_izmajlov',
#  'dfd179071_izmajlov',
#  '68153d35e_izmajlov',
#  '2c6c62b54_izmajlov',
#  'deabe0f4c_izmajlov',
#  '58e056e12_izmajlov',
#  'c0085a739',
#  '241f0f867_izmajlov',
#  '4c2064b00_izmajlov',
#  '1931ccfdd_izmajlov',
#  'f553483a0',
#  '14d2c6d95_izmajlov',
#  '9370aa48d_izmajlov',
#  'da22ed2b8_izmajlov',
#  '58e2e02e6_izmajlov',
#  '920a04ee2_izmajlov',
#  'a7ac690a8_izmajlov',
#  'fcda960ae_izmajlov',
#  'a8b721722_izmajlov',
#  'fa422ab84',
#  '9fd594eec_izmajlov',
#  '1e8e233aa',
#  '0700acbe1_izmajlov',
#  '66146c12d_izmajlov',
#  '91f701ba2_izmajlov',
#  '703885424_izmajlov',
#  '2f7b0f5b5_izmajlov',
#  '2e103d632_izmajlov',
#  '1bf8c2597_izmajlov',
#  '22eb11620_izmajlov',
#  'b0fcfeab8_izmajlov',
#  '939f628a7_izmajlov',
#  'ed8951a75_izmajlov',
#  'dfde54714_izmajlov',
#  'b791ce9aa_izmajlov',
#  'eeb9cd3aa_izmajlov',
#  '58232a6fb_izmajlov',
#  '24b2da056_izmajlov',
#  '2d5b0ff08',
#  '1dd7bca9f_izmajlov',
#  'bbe4423a3_izmajlov',
#  'ed8ff54b5',
#  '73687e512_izmajlov',
#  'd4c72ccf2',
#  '469630e5c_izmajlov',
#  '21a3176c5',
#  'ab515bdeb_izmajlov',
#  '2ef57c650_izmajlov',
#  '62e59a501_izmajlov',
#  '5c6487af1_izmajlov',
#  'a3ef69ad5_izmajlov',
#  '435f27009_izmajlov',
#  'f190486d6_izmajlov',
#  'e438105db_izmajlov',
#  'e176a204a_izmajlov',
#  '1702b5bf0_izmajlov',
#  '8618bc1fd_izmajlov',
#  '609784003',
#  '34b2a678e_izmajlov',
#  '190db8488_izmajlov',
#  'c906cd268_izmajlov',
#  'adf357c9b_izmajlov',
#  '8d7bfb911_izmajlov',
#  '9281abeea_izmajlov',
#  'non_zero_mean_izmajlov',
#  'non_zero_std_izmajlov',
#  'non_zero_max_izmajlov',
#  'non_zero_min_izmajlov',
#  'non_zero_sum_izmajlov',
#  'non_zero_skewness_izmajlov',
#  'non_zero_kurtosis_izmajlov',
#  'non_zero_median_izmajlov',
#  'non_zero_q1_izmajlov',
#  'non_zero_q3_izmajlov',
#  'non_zero_log_mean_izmajlov',
#  'non_zero_log_std_izmajlov',
#  'non_zero_log_sum_izmajlov',
#  'non_zero_log_skewness_izmajlov',
#  'non_zero_log_kurtosis_izmajlov',
#  'non_zero_count_izmajlov',
#  'pca0_izmajlov',
#  'pca1_izmajlov',
#  'pca2_izmajlov',
#  'pca3_izmajlov',
#  'pca4_izmajlov',
#  'pca5_izmajlov',
#  'pca6_izmajlov',
#  'pca7_izmajlov',
#  'pca8_izmajlov',
#  'pca9_izmajlov',
#  'pca10_izmajlov',
#  'pca11_izmajlov',
#  'pca12_izmajlov',
#  'pca13_izmajlov',
#  'pca14_izmajlov',
#  'pca15_izmajlov',
#  'pca16_izmajlov',
#  'pca17_izmajlov',
#  'pca19_izmajlov',
#  'pca21_izmajlov',
#  'pca22_izmajlov',
#  'pca23_izmajlov',
#  'pca24_izmajlov',
#  'pca25_izmajlov',
#  'pca27_izmajlov',
#  'pca28_izmajlov',
#  'pca29_izmajlov',
#  'pca30_izmajlov',
#  'pca31_izmajlov',
#  'pca32_izmajlov',
#  'pca33_izmajlov',
#  'pca35_izmajlov',
#  'pca37_izmajlov',
#  'pca38_izmajlov',
#  'pca39_izmajlov',
#  'pca40_izmajlov',
#  'pca41_izmajlov',
#  'pca42_izmajlov',
#  'pca43_izmajlov',
#  'pca44_izmajlov',
#  'pca45_izmajlov',
#  'pca47_izmajlov',
#  'pca48_izmajlov',
#  'pca50_izmajlov',
#  'pca51_izmajlov',
#  'pca52_izmajlov',
#  'pca53_izmajlov',
#  'pca54_izmajlov',
#  'pca55_izmajlov',
#  'pca56_izmajlov',
#  'pca57_izmajlov',
#  'pca58_izmajlov',
#  'pca59_izmajlov',
#  'pca60_izmajlov',
#  'pca61_izmajlov',
#  'pca62_izmajlov',
#  'pca63_izmajlov',
#  'pca64_izmajlov',
#  'pca65_izmajlov',
#  'pca66_izmajlov',
#  'pca67_izmajlov',
#  'pca68_izmajlov',
#  'pca69_izmajlov',
#  'pca72_izmajlov',
#  'pca74_izmajlov',
#  'pca75_izmajlov',
#  'pca76_izmajlov',
#  'pca77_izmajlov',
#  'pca78_izmajlov',
#  'pca79_izmajlov',
#  'pca83_izmajlov',
#  'pca84_izmajlov',
#  'pca85_izmajlov',
#  'pca86_izmajlov',
#  'pca88_izmajlov',
#  'pca89_izmajlov',
#  'pca90_izmajlov',
#  'pca91_izmajlov',
#  'pca92_izmajlov',
#  'pca94_izmajlov',
#  'pca95_izmajlov',
#  'pca96_izmajlov',
#  'pca97_izmajlov',
#  'pca103_izmajlov',
#  'pca104_izmajlov',
#  'pca105_izmajlov',
#  'pca107_izmajlov',
#  'pca109_izmajlov',
#  'pca111_izmajlov',
#  'pca113_izmajlov',
#  'pca116_izmajlov',
#  'pca117_izmajlov',
#  'pca118_izmajlov',
#  'pca119_izmajlov',
#  'pca121_izmajlov',
#  'pca122_izmajlov',
#  'pca123_izmajlov',
#  'pca126_izmajlov',
#  'pca128_izmajlov',
#  'pca129_izmajlov',
#  'pca130_izmajlov',
#  'pca131_izmajlov',
#  'pca132_izmajlov',
#  'pca133_izmajlov',
#  'pca136_izmajlov',
#  'pca137_izmajlov',
#  'pca142_izmajlov',
#  'pca144_izmajlov',
#  'pca147_izmajlov',
#  'pca148_izmajlov',
#  'pca150_izmajlov',
#  'pca156_izmajlov',
#  'pca158_izmajlov',
#  'pca160_izmajlov',
#  'pca162_izmajlov',
#  'pca164_izmajlov',
#  'pca166_izmajlov',
#  'pca170_izmajlov',
#  'pca171_izmajlov',
#  'pca173_izmajlov',
#  'pca176_izmajlov',
#  'pca178_izmajlov',
#  'pca182_izmajlov',
#  'pca183_izmajlov',
#  'pca184_izmajlov',
#  'pca185_izmajlov',
#  'pca193_izmajlov',
#  'pca194_izmajlov',
#  'pca195_izmajlov',
#  'pca196_izmajlov',
#  'pca198_izmajlov',
#  'pca199_izmajlov',
#  'pca202_izmajlov',
#  'pca203_izmajlov',
#  'pca204_izmajlov',
#  'pca205_izmajlov',
#  'pca206_izmajlov',
#  'pca207_izmajlov',
#  'pca208_izmajlov',
#  'pca211_izmajlov',
#  'pca212_izmajlov',
#  'pca213_izmajlov',
#  'pca215_izmajlov',
#  'pca216_izmajlov',
#  'pca218_izmajlov',
#  'pca223_izmajlov',
#  'pca225_izmajlov',
#  'pca227_izmajlov',
#  'pca228_izmajlov',
#  'pca232_izmajlov',
#  'pca233_izmajlov',
#  'pca235_izmajlov',
#  'pca236_izmajlov',
#  'pca237_izmajlov',
#  'pca239_izmajlov',
#  'pca242_izmajlov',
#  'pca243_izmajlov',
#  'pca246_izmajlov',
#  'pca247_izmajlov',
#  'pca252_izmajlov',
#  'pca253_izmajlov',
#  'pca259_izmajlov',
#  'pca263_izmajlov',
#  'pca268_izmajlov',
#  'pca269_izmajlov',
#  'pca270_izmajlov',
#  'pca277_izmajlov',
#  'pca278_izmajlov',
#  'pca287_izmajlov',
#  'pca288_izmajlov',
#  'pca289_izmajlov',
#  'pca290_izmajlov',
#  'pca293_izmajlov',
#  'pca295_izmajlov',
#  'pca297_izmajlov',
#  'pca298_izmajlov',
#  'pca300_izmajlov',
#  'pca304_izmajlov',
#  'pca305_izmajlov',
#  'pca306_izmajlov',
#  'pca309_izmajlov',
#  'pca312_izmajlov',
#  'pca314_izmajlov',
#  'pca320_izmajlov',
#  'pca323_izmajlov',
#  'pca327_izmajlov',
#  'pca328_izmajlov',
#  'pca334_izmajlov',
#  'pca335_izmajlov',
#  'pca340_izmajlov',
#  'pca343_izmajlov',
#  'pca347_izmajlov',
#  'pca348_izmajlov',
#  'pca350_izmajlov',
#  'pca351_izmajlov',
#  'pca353_izmajlov',
#  'tsvd6_izmajlov',
#  'tsvd8_izmajlov',
#  'tsvd9_izmajlov',
#  'tsvd11_izmajlov',
#  'tsvd18_izmajlov',
#  'tsvd21_izmajlov',
#  'tsvd22_izmajlov',
#  'tsvd23_izmajlov',
#  'tsvd29_izmajlov',
#  'tsvd31_izmajlov',
#  'tsvd34_izmajlov',
#  'tsvd42_izmajlov',
#  'tsvd43_izmajlov',
#  'fa2_izmajlov',
#  'fa3_izmajlov',
#  'fa4_izmajlov',
#  'fa7_izmajlov',
#  'fa9_izmajlov',
#  'fa18_izmajlov',
#  'fa20_izmajlov',
#  'fa24_izmajlov',
#  'fa25_izmajlov',
#  'fa26_izmajlov',
#  'fa27_izmajlov',
#  'fa30_izmajlov',
#  'fa31_izmajlov',
#  'fa32_izmajlov',
#  'fa36_izmajlov',
#  'fa37_izmajlov',
#  'fa39_izmajlov',
#  'fa41_izmajlov',
#  'fa42_izmajlov',
#  'fa43_izmajlov',
#  'fa44_izmajlov',
#  'fa45_izmajlov',
#  'fa47_izmajlov',
#  'gauss6_izmajlov',
#  'gauss16_izmajlov',
#  'gauss17_izmajlov',
#  'gauss23_izmajlov',
#  'gauss24_izmajlov',
#  'gauss25_izmajlov',
#  'gauss28_izmajlov',
#  'gauss30_izmajlov',
#  'gauss34_izmajlov',
#  'gauss37_izmajlov',
#  'gauss40_izmajlov',
#  'gauss44_izmajlov',
#  'gauss46_izmajlov',
#  'srp0_izmajlov',
#  'srp3_izmajlov',
#  'srp4_izmajlov',
#  'srp8_izmajlov',
#  'srp18_izmajlov',
#  'srp22_izmajlov',
#  'srp23_izmajlov',
#  'srp31_izmajlov',
#  'srp40_izmajlov',
#  'srp41_izmajlov',
#  'srp48_izmajlov',
#  'srp49_izmajlov',
#  '26ab20ff9/6786ea46d',
#  '15ace8c9f/26ab20ff9',
#  '26ab20ff9/fb387ea33',
#  '26ab20ff9/9fd594eec',
#  '26ab20ff9/3bdee45be',
#  '26ab20ff9/66ace2992',
#  '6786ea46d/fb387ea33',
#  '6786ea46d/f190486d6',
#  '15ace8c9f/251d1aa17',
#  'b6fa5a5fd/fb387ea33',
#  'b6fa5a5fd/f190486d6',
#  '3bdee45be/b6fa5a5fd',
#  '5c6487af1/fb387ea33',
#  '08e89cc54/fb387ea33',
#  '3e1100230/fb387ea33',
#  '91f701ba2/fb387ea33',
#  '251d1aa17/9fd594eec',
#  '5e1085022/9fd594eec',
#  'non_zero_mean_crowded',
#  'non_zero_q1_crowded',
#  'non_zero_log_mean_crowded',
#  'non_zero_log_sum_crowded',
#  'non_zero_log_std_crowded',
#  'non_zero_log_kurtosis_crowded',
#  'non_zero_count_crowded',
#  'unique_values',
#  'zero_count',
#  'tsne1',
#  'pca6_crowded',
#  'pca7_crowded',
#  'pca9_crowded',
#  'pca21_crowded',
#  'pca27_crowded',
#  'pca33_crowded',
#  'pca36_crowded',
#  'pca37_crowded',
#  'pca40_crowded',
#  'pca42_crowded',
#  'pca53_crowded',
#  'pca56_crowded',
#  'pca57_crowded',
#  'pca58_crowded',
#  'pca61_crowded',
#  'pca62_crowded',
#  'pca67_crowded',
#  'pca71_crowded',
#  'pca86_crowded',
#  'pca88_crowded',
#  'pca91_crowded',
#  'pca93_crowded',
#  'pca95_crowded',
#  'pca101_crowded',
#  'pca104_crowded',
#  'pca106_crowded',
#  'pca109_crowded',
#  'pca110_crowded',
#  'pca111_crowded',
#  'pca113_crowded',
#  'pca114_crowded',
#  'pca115_crowded',
#  'pca120_crowded',
#  'pca122_crowded',
#  'pca123_crowded',
#  'pca142_crowded',
#  'pca144_crowded',
#  'pca145_crowded',
#  'pca148_crowded',
#  'pca149_crowded',
#  'pca151_crowded',
#  'pca166_crowded',
#  'pca167_crowded',
#  'pca170_crowded',
#  'pca172_crowded',
#  'pca175_crowded',
#  'pca180_crowded',
#  'pca181_crowded',
#  'pca184_crowded',
#  'pca192_crowded',
#  'pca193_crowded',
#  'pca195_crowded',
#  'pca204_crowded',
#  'pca213_crowded',
#  'pca214_crowded',
#  'pca219_crowded',
#  'pca222_crowded',
#  'pca224_crowded',
#  'pca227_crowded',
#  'pca228_crowded',
#  'pca229_crowded',
#  'pca233_crowded',
#  'pca234_crowded',
#  'pca237_crowded',
#  'pca239_crowded',
#  'pca244_crowded',
#  'pca245_crowded',
#  'pca250_crowded',
#  'pca251_crowded',
#  'pca253_crowded',
#  'pca256_crowded',
#  'pca262_crowded',
#  'pca266_crowded',
#  'pca269_crowded',
#  'pca270_crowded',
#  'pca272_crowded',
#  'pca273_crowded',
#  'pca274_crowded',
#  'pca278_crowded',
#  'pca279_crowded',
#  'pca283_crowded',
#  'pca285_crowded',
#  'pca288_crowded',
#  'pca289_crowded',
#  'pca290_crowded',
#  'pca295_crowded',
#  'pca306_crowded',
#  'pca311_crowded',
#  'pca312_crowded',
#  'pca316_crowded',
#  'pca317_crowded',
#  'pca318_crowded',
#  'pca319_crowded',
#  'pca322_crowded',
#  'pca326_crowded',
#  'pca328_crowded',
#  'pca332_crowded',
#  'pca333_crowded',
#  'pca337_crowded',
#  'pca338_crowded',
#  'pca344_crowded',
#  'pca348_crowded',
#  'pca349_crowded',
#  'pca351_crowded',
#  'pca353_crowded',
#  'pca354_crowded',
#  'pca355_crowded',
#  'pca357',
#  'pca358',
#  'pca361',
#  'pca365',
#  'pca367',
#  'pca369',
#  'pca371',
#  'pca372',
#  'pca376',
#  'pca377',
#  'pca381',
#  'pca385',
#  'pca389',
#  'pca398',
#  'pca399',
#  'pca402',
#  'pca407',
#  'pca409',
#  'pca410',
#  'pca411',
#  'pca414',
#  'pca417',
#  'pca418',
#  'pca423',
#  'pca424',
#  'pca426',
#  'pca431',
#  'pca433',
#  'pca436',
#  'pca437',
#  'pca441',
#  'pca442',
#  'pca444',
#  'pca445',
#  'pca451',
#  'pca453',
#  'pca454',
#  'pca459',
#  'pca462',
#  'pca466',
#  'pca468',
#  'pca469',
#  'pca472',
#  'pca475',
#  'pca479',
#  'pca480',
#  'pca489',
#  'pca492',
#  'pca493',
#  'pca494',
#  'pca496',
#  'pca498',
#  'tsvd10_crowded',
#  'tsvd13_crowded',
#  'tsvd21_crowded',
#  'tsvd22_crowded',
#  'tsvd24_crowded',
#  'tsvd29_crowded',
#  'tsvd30_crowded',
#  'tsvd31_crowded',
#  'tsvd33_crowded',
#  'tsvd35_crowded',
#  'tsvd38_crowded',
#  'fa3_crowded',
#  'fa5_crowded',
#  'fa8_crowded',
#  'fa9_crowded',
#  'fa10_crowded',
#  'fa11_crowded',
#  'fa13_crowded',
#  'fa16_crowded',
#  'fa19_crowded',
#  'fa21_crowded',
#  'fa24_crowded',
#  'fa27_crowded',
#  'fa29_crowded',
#  'fa30_crowded',
#  'fa32_crowded',
#  'fa38_crowded',
#  'srp4_crowded',
#  'srp10_crowded',
#  'srp12_crowded',
#  'srp21_crowded',
#  'srp23_crowded',
#  'srp30_crowded',
#  'srp31_crowded',
#  'srp33_crowded',
#  'grp2',
#  'grp4',
#  'grp7',
#  'grp13',
#  'grp14',
#  'grp26',
#  'grp27',
#  'grp31',
#  'grp36',
#  'grp39',
#  'grp40',
#  'grp41',
#  'grp42',
#  'max_man',
#  'nzm',
#  'nzs',
#  'manif_0',
#  'manif_9',
#  'gauss16_crowded',
#  'gauss21_crowded',
#  'gauss37_crowded',
#  'gauss12_crowded',
#  'gauss29_crowded',
#  'gauss5_crowded',
#  'gauss43_crowded',
#  'gauss6_crowded',
#  'gauss2_crowded',
#  'gauss49_crowded',
#  'gauss25_crowded',
#  'gauss1_crowded',
#  'gauss27_crowded',
#  'mean_tsvd',
#  'gp_clustering_ii_79',
#  'gp_clustering_ii_85',
#  'gp_clustering_ii_88',
#  'gp_clustering_ii_96',
#  'gp_clustering_ii_98',
#  'gp_clustering_ii_100',
#  'gp_clustering_ii_103',
#  'gp_clustering_ii_104',
#  'gp_clustering_ii_105',
#  'gp_clustering_ii_107',
#  'gp_clustering_ii_108',
#  'gp_clustering_ii_109',
#  'gp_clustering_ii_110',
#  'gp_clustering_ii_111',
#  'gp_clustering_ii_112',
#  'gp_clustering_ii_113',
#  'gp_clustering_ii_114',
#  'gp_clustering_ii_116',
#  'gp_clustering_ii_129',
#  'gp_clustering_ii_136',
#  'gp_clustering_ii_139',
#  'gp_clustering_ii_140',
#  'gp_clustering_ii_146',
#  'gp_clustering_ii_147',
#  'gp_clustering_ii_150',
#  'gp_clustering_ii_151',
#  'gp_clustering_ii_152',
#  'gp_clustering_ii_153',
#  'gp_clustering_ii_155',
#  'gp_clustering_ii_157',
#  'gp_clustering_ii_164',
#  'gp_clustering_ii_175',
#  'gp_clustering_ii_178',
#  'gp_clustering_ii_196',
#  'gp_clustering_ii_198',
#  'gp_clustering_ii_208',
#  'gp_clustering_ii_214',
#  'gp_clustering_ii_217',
#  'gp_clustering_ii_220',
#  'gp_clustering_ii_226',
#  'gp_clustering_ii_229',
#  'gp_clustering_ii_238',
#  'gp_clustering_ii_247',
#  'gp_clustering_ii_262',
#  'gp_clustering_ii_265',
#  'gp_clustering_ii_266',
#  'gp_clustering_ii_268',
#  'gp_clustering_ii_274',
#  'gp_clustering_ii_275']

# %%
# %%time
new_crowded_features_data_store = f'{FEATURES_PATH}crowded_features_v2_data_store.pkl'
print( "Saving data...")
with open(os.path.abspath(new_crowded_features_data_store), 'wb') as f:
    pickle.dump((total_df,
                 target,
                 range(0, len(target)),
                 range(len(target), len(total_df))),
                f, protocol = pickle.HIGHEST_PROTOCOL)
    print('Saved to', os.path.abspath(new_crowded_features_data_store))

new_crowded_features_data_store = f'{FEATURES_PATH}crowded_features_v2_boosted_data_store.pkl'
print( "Saving data...")
with open(os.path.abspath(new_crowded_features_data_store), 'wb') as f:
    pickle.dump((total_df[remaining_vars],
                 target,
                 range(0, len(target)),
                 range(len(target), len(total_df))),
                f, protocol = pickle.HIGHEST_PROTOCOL)
    print('Saved to', os.path.abspath(new_crowded_features_data_store))
# Out:
# Saving data...
# Saved to C:\santander-value-prediction-challenge\features\crowded_features_v2_data_store.pkl
# Saving data...
# Saved to C:\santander-value-prediction-challenge\features\crowded_features_v2_boosted_data_store.pkl
# Wall time: 14.8 s

# %% [markdown]
# # 4. Modelling

# %% [markdown]
# ## 4.1 Sections to add models to train

# %% [markdown]
# ### 4.1.1 LightGBM

# %%
def run_lgb(train_X, train_y, val_X, val_y, test_X, seed = RANDOM_STATE):
    params = {
        "objective" : "regression",
        "metric" : "rmse",
        "num_leaves" : 361,#40
        'max_depth': 21,
        "learning_rate" : 0.004,#0.005
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.4,#0.6
        "bagging_frequency" : 5,
        "verbosity" : -1,
        'num_threads' : 4,
        "seed": seed
    }
    
    start_time = time.time()
    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    model = lgb.train(params, lgtrain, 10000, 
                      valid_sets=[lgtrain, lgval], 
                      verbose_eval=200, 
                      early_stopping_rounds=200)
    print('Model training done in {} seconds.'.format(time.time() - start_time))
    
    pred_test_y = np.expm1(model.predict(test_X, num_iteration=model.best_iteration))
    pred_oof_log = model.predict(val_X, num_iteration=model.best_iteration)
    return pred_test_y, pred_oof_log, model

# %% [markdown]
# ## 4.2 General function to run models with cv

# %% [markdown]
# ### 4.2.1 Create custom folds

# %%
def get_20_cv_splits(data, output_folder):
    stratify_classes = data.target.apply(lambda x: int(np.log10(x)))
    splits = {}
    for random_state in range(20):
        column = np.zeros(data.shape[0])
        sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=random_state)
        for i, (_, test_index) in enumerate(sss.split(data, stratify_classes)):
            column[test_index] = i

        splits["split{}".format(random_state)] = column

    pd.DataFrame(splits, index=data.index).to_csv(f'{output_folder}cv_splits.csv')

# %%
# function to generate 100 folds from create_folds_from_cv_splits func
def create_folds_from_cv_splits(in_path = f'{FOLDS_PATH}cv_splits.csv'):
    
    cv_splits = pd.read_csv(in_path)
    folds_list = []
    for ind, i in enumerate(cv_splits.columns[1:]):
        folds = list(set(cv_splits[i].values))
        folds_list.append([])
        for m in folds:
            val_idx = list(cv_splits[cv_splits[i]==m].index)
            train_idx = list(set(list(cv_splits.index)) - set(val_idx))
            folds_list[ind].append((train_idx, val_idx))
    with open(f'{FOLDS_PATH}custom_cv.pkl', 'wb') as f:
        pickle.dump(folds_list, f)
    return folds_list

# %% [markdown]
# ### 4.2.2 General logic to train single function

# %%
def run_calculations(X, test, big_cv_folds, func_name = None):
    if not func_name:
        return print('The function to run is not defined')
    else:
        y_oof_20_preds = []
        fold_errors_20_preds =[]
        avg_test_pred_20_preds = []
        models_20_preds = []
        
        start_time = time.time()
        for ind, cv_folds in enumerate(big_cv_folds):
#             print('Fitting big fold', ind+1, 'out of', len(big_cv_folds))
            y_oof = np.zeros((y.shape[0]))
            fold_errors =[]
            pred_test_list = []
            models = []
            
            for i, (train_index, val_index) in enumerate(cv_folds):
                print('Fitting big fold', ind+1, 'out of', len(big_cv_folds),
                      'and sub fold', i+1, 'out of', len(cv_folds))
                X_train, X_val  = X.iloc[train_index], X.iloc[val_index]
                y_train, y_val = y[train_index], y[val_index]

                # part to include additional functions
                if func_name == 'lgb':
                    pred_test_y, pred_oof_log, clf = run_lgb(X_train, y_train, X_val, y_val, test,
                                                             seed = (RANDOM_STATE + ind*i))
                    models.append(clf)
                else:
                    return print('The function to run is not correct')

                y_oof[val_index] = pred_oof_log
                curr_fe = np.sqrt(mean_squared_error(y_val, pred_oof_log))
                print(f'Fold error {curr_fe}')
                fold_errors.append(curr_fe)
                pred_test_list.append(list(pred_test_y))
                print('Time passed: {} seconds.'.format(time.time() - start_time))

            print('Average big fold', ind+1, 'error:', np.sqrt(mean_squared_error(y, y_oof)))
            total_fe_std = round(np.std(fold_errors), 5)
            print(f'Total big fold {ind+1} std {total_fe_std}')
            avg_test_pred = np.mean(pred_test_list, axis=0)
            
            avg_test_pred_20_preds.append(avg_test_pred)
            fold_errors_20_preds.append(fold_errors)
            y_oof_20_preds.append(y_oof)
            models_20_preds.append(models)
            
        return y_oof_20_preds, avg_test_pred_20_preds, fold_errors_20_preds, models_20_preds

# %% [markdown]
# ## 4.3 Run experiments with different data

# %% [markdown]
# ### 4.3.1 generate or load custom cv folds

# %%
# %%time
LOAD_CV = True

if LOAD_CV:
    with open(f'{FOLDS_PATH}custom_cv.pkl', 'rb') as f:
        cv_folds = pickle.load(f)
else:
    get_20_cv_splits(train_df, FOLDS_PATH)
    cv_folds = create_folds_from_cv_splits()
# Out:
# Wall time: 29 ms

# %% [markdown]
# ### 4.3.2 run models

# %%
# %%time
y_oof_lgb, avg_test_pred_20, fold_errors, models_all = run_calculations(X[remaining_vars],
                                                                        test[remaining_vars], cv_folds, 'lgb')
# Out:
# Fitting big fold 1 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.1276	valid_1's rmse: 1.42196
# [400]	training's rmse: 0.791611	valid_1's rmse: 1.34043
# [600]	training's rmse: 0.582924	valid_1's rmse: 1.32145
# [800]	training's rmse: 0.440204	valid_1's rmse: 1.31733
# [1000]	training's rmse: 0.336647	valid_1's rmse: 1.31644
# [1200]	training's rmse: 0.261889	valid_1's rmse: 1.31598
# [1400]	training's rmse: 0.206897	valid_1's rmse: 1.31531
# [1600]	training's rmse: 0.165969	valid_1's rmse: 1.31509
# Early stopping, best iteration is:
# [1571]	training's rmse: 0.171252	valid_1's rmse: 1.31505
# Model training done in 98.60400986671448 seconds.
# Fold error 1.3150473565745955
# Time passed: 105.04500651359558 seconds.
# Fitting big fold 1 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12361	valid_1's rmse: 1.39054
# [400]	training's rmse: 0.788613	valid_1's rmse: 1.29773
# [600]	training's rmse: 0.581796	valid_1's rmse: 1.27601
# [800]	training's rmse: 0.440773	valid_1's rmse: 1.26821
# [1000]	training's rmse: 0.339699	valid_1's rmse: 1.26477
# [1200]	training's rmse: 0.267503	valid_1's rmse: 1.26192
# [1400]	training's rmse: 0.213867	valid_1's rmse: 1.26073
# [1600]	training's rmse: 0.173405	valid_1's rmse: 1.25988
# [1800]	training's rmse: 0.142107	valid_1's rmse: 1.25923
# [2000]	training's rmse: 0.117905	valid_1's rmse: 1.25893
# [2200]	training's rmse: 0.0993202	valid_1's rmse: 1.25842
# [2400]	training's rmse: 0.0851217	valid_1's rmse: 1.25832
# [2600]	training's rmse: 0.0738964	valid_1's rmse: 1.25815
# [2800]	training's rmse: 0.0650025	valid_1's rmse: 1.25771
# [3000]	training's rmse: 0.0580575	valid_1's rmse: 1.25749
# [3200]	training's rmse: 0.0523377	valid_1's rmse: 1.25737
# [3400]	training's rmse: 0.047559	valid_1's rmse: 1.25728
# [3600]	training's rmse: 0.0435125	valid_1's rmse: 1.25719
# [3800]	training's rmse: 0.0401111	valid_1's rmse: 1.25706
# [4000]	training's rmse: 0.0371251	valid_1's rmse: 1.25693
# [4200]	training's rmse: 0.0346131	valid_1's rmse: 1.25689
# [4400]	training's rmse: 0.0324134	valid_1's rmse: 1.25685
# [4600]	training's rmse: 0.0303838	valid_1's rmse: 1.25682
# Early stopping, best iteration is:
# [4534]	training's rmse: 0.031023	valid_1's rmse: 1.25678
# Model training done in 363.3240237236023 seconds.
# Fold error 1.2567787347748474
# Time passed: 497.0830271244049 seconds.
# Fitting big fold 1 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12351	valid_1's rmse: 1.39426
# [400]	training's rmse: 0.787045	valid_1's rmse: 1.31222
# [600]	training's rmse: 0.579333	valid_1's rmse: 1.29337
# [800]	training's rmse: 0.43776	valid_1's rmse: 1.28915
# [1000]	training's rmse: 0.336877	valid_1's rmse: 1.28858
# [1200]	training's rmse: 0.264296	valid_1's rmse: 1.28798
# [1400]	training's rmse: 0.212154	valid_1's rmse: 1.2877
# Early stopping, best iteration is:
# [1394]	training's rmse: 0.213451	valid_1's rmse: 1.28762
# Model training done in 130.38700985908508 seconds.
# Fold error 1.2876193483023546
# Time passed: 633.9470381736755 seconds.
# Fitting big fold 1 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11676	valid_1's rmse: 1.45845
# [400]	training's rmse: 0.78288	valid_1's rmse: 1.37808
# [600]	training's rmse: 0.576413	valid_1's rmse: 1.3606
# [800]	training's rmse: 0.435354	valid_1's rmse: 1.35596
# [1000]	training's rmse: 0.334494	valid_1's rmse: 1.35413
# [1200]	training's rmse: 0.262503	valid_1's rmse: 1.35423
# Early stopping, best iteration is:
# [1011]	training's rmse: 0.329819	valid_1's rmse: 1.35406
# Model training done in 97.24400424957275 seconds.
# Fold error 1.3540603755719378
# Time passed: 735.9450433254242 seconds.
# Fitting big fold 1 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12402	valid_1's rmse: 1.41485
# [400]	training's rmse: 0.78758	valid_1's rmse: 1.33163
# [600]	training's rmse: 0.580292	valid_1's rmse: 1.31331
# [800]	training's rmse: 0.438458	valid_1's rmse: 1.30916
# [1000]	training's rmse: 0.336989	valid_1's rmse: 1.30796
# [1200]	training's rmse: 0.265324	valid_1's rmse: 1.3078
# Early stopping, best iteration is:
# [1194]	training's rmse: 0.267003	valid_1's rmse: 1.30777
# Model training done in 105.934006690979 seconds.
# Fold error 1.3077704660816
# Time passed: 847.2960505485535 seconds.
# Average big fold 1 error: 1.3106699987016512
# Total big fold 1 std 0.03206
# Fitting big fold 2 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11794	valid_1's rmse: 1.44255
# [400]	training's rmse: 0.781479	valid_1's rmse: 1.36964
# [600]	training's rmse: 0.575407	valid_1's rmse: 1.35405
# [800]	training's rmse: 0.434449	valid_1's rmse: 1.35058
# [1000]	training's rmse: 0.332015	valid_1's rmse: 1.34978
# [1200]	training's rmse: 0.257627	valid_1's rmse: 1.34979
# Early stopping, best iteration is:
# [1179]	training's rmse: 0.264397	valid_1's rmse: 1.34964
# Model training done in 78.04400396347046 seconds.
# Fold error 1.3496377748552892
# Time passed: 930.3600568771362 seconds.
# Fitting big fold 2 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12629	valid_1's rmse: 1.3626
# [400]	training's rmse: 0.789988	valid_1's rmse: 1.2586
# [600]	training's rmse: 0.581083	valid_1's rmse: 1.22948
# [800]	training's rmse: 0.438953	valid_1's rmse: 1.22155
# [1000]	training's rmse: 0.3366	valid_1's rmse: 1.22064
# Early stopping, best iteration is:
# [905]	training's rmse: 0.381149	valid_1's rmse: 1.22002
# Model training done in 95.93300747871399 seconds.
# Fold error 1.2200196712441895
# Time passed: 1030.7630641460419 seconds.
# Fitting big fold 2 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12418	valid_1's rmse: 1.39444
# [400]	training's rmse: 0.788999	valid_1's rmse: 1.29355
# [600]	training's rmse: 0.582742	valid_1's rmse: 1.26724
# [800]	training's rmse: 0.441075	valid_1's rmse: 1.25754
# [1000]	training's rmse: 0.339179	valid_1's rmse: 1.25476
# [1200]	training's rmse: 0.265401	valid_1's rmse: 1.25277
# [1400]	training's rmse: 0.213486	valid_1's rmse: 1.25174
# [1600]	training's rmse: 0.174305	valid_1's rmse: 1.25096
# [1800]	training's rmse: 0.143966	valid_1's rmse: 1.2503
# [2000]	training's rmse: 0.120836	valid_1's rmse: 1.24966
# [2200]	training's rmse: 0.102624	valid_1's rmse: 1.2495
# [2400]	training's rmse: 0.0885002	valid_1's rmse: 1.24956
# Early stopping, best iteration is:
# [2241]	training's rmse: 0.0993331	valid_1's rmse: 1.24944
# Model training done in 196.1080105304718 seconds.
# Fold error 1.249440635891122
# Time passed: 1239.7440769672394 seconds.
# Fitting big fold 2 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11811	valid_1's rmse: 1.44246
# [400]	training's rmse: 0.785388	valid_1's rmse: 1.35714
# [600]	training's rmse: 0.579968	valid_1's rmse: 1.33715
# [800]	training's rmse: 0.440073	valid_1's rmse: 1.33316
# [1000]	training's rmse: 0.340452	valid_1's rmse: 1.33196
# [1200]	training's rmse: 0.269678	valid_1's rmse: 1.33167
# [1400]	training's rmse: 0.21635	valid_1's rmse: 1.33149
# Early stopping, best iteration is:
# [1297]	training's rmse: 0.24183	valid_1's rmse: 1.33105
# Model training done in 118.07500648498535 seconds.
# Fold error 1.331049521744661
# Time passed: 1363.7110838890076 seconds.
# Fitting big fold 2 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12588	valid_1's rmse: 1.38882
# [400]	training's rmse: 0.789787	valid_1's rmse: 1.31359
# [600]	training's rmse: 0.581389	valid_1's rmse: 1.2987
# [800]	training's rmse: 0.4397	valid_1's rmse: 1.29813
# Early stopping, best iteration is:
# [671]	training's rmse: 0.525153	valid_1's rmse: 1.29782
# Model training done in 68.36800646781921 seconds.
# Fold error 1.2978217925823858
# Time passed: 1435.6870872974396 seconds.
# Average big fold 2 error: 1.3108628515909866
# Total big fold 2 std 0.04867
# Fitting big fold 3 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.13073	valid_1's rmse: 1.40822
# [400]	training's rmse: 0.7957	valid_1's rmse: 1.3275
# [600]	training's rmse: 0.587645	valid_1's rmse: 1.30981
# [800]	training's rmse: 0.444493	valid_1's rmse: 1.30505
# [1000]	training's rmse: 0.341541	valid_1's rmse: 1.30375
# [1200]	training's rmse: 0.266516	valid_1's rmse: 1.30404
# Early stopping, best iteration is:
# [1060]	training's rmse: 0.316802	valid_1's rmse: 1.3037
# Model training done in 69.98900651931763 seconds.
# Fold error 1.303704560836813
# Time passed: 1510.2700905799866 seconds.
# Fitting big fold 3 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12478	valid_1's rmse: 1.37603
# [400]	training's rmse: 0.789754	valid_1's rmse: 1.27618
# [600]	training's rmse: 0.583004	valid_1's rmse: 1.25053
# [800]	training's rmse: 0.440863	valid_1's rmse: 1.24394
# [1000]	training's rmse: 0.340296	valid_1's rmse: 1.2402
# [1200]	training's rmse: 0.269078	valid_1's rmse: 1.23958
# Early stopping, best iteration is:
# [1165]	training's rmse: 0.279644	valid_1's rmse: 1.23913
# Model training done in 117.1260085105896 seconds.
# Fold error 1.2391312760055018
# Time passed: 1632.8410980701447 seconds.
# Fitting big fold 3 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11891	valid_1's rmse: 1.43923
# [400]	training's rmse: 0.784733	valid_1's rmse: 1.35608
# [600]	training's rmse: 0.57838	valid_1's rmse: 1.33572
# [800]	training's rmse: 0.437063	valid_1's rmse: 1.32999
# [1000]	training's rmse: 0.335424	valid_1's rmse: 1.32768
# [1200]	training's rmse: 0.263322	valid_1's rmse: 1.32654
# [1400]	training's rmse: 0.209684	valid_1's rmse: 1.32589
# [1600]	training's rmse: 0.170661	valid_1's rmse: 1.32528
# [1800]	training's rmse: 0.13876	valid_1's rmse: 1.32493
# [2000]	training's rmse: 0.114309	valid_1's rmse: 1.32451
# [2200]	training's rmse: 0.095485	valid_1's rmse: 1.32423
# [2400]	training's rmse: 0.0807582	valid_1's rmse: 1.32399
# [2600]	training's rmse: 0.0693301	valid_1's rmse: 1.32384
# [2800]	training's rmse: 0.0603201	valid_1's rmse: 1.32386
# Early stopping, best iteration is:
# [2608]	training's rmse: 0.0689288	valid_1's rmse: 1.32382
# Model training done in 230.9570186138153 seconds.
# Fold error 1.3238153760656464
# Time passed: 1880.1871130466461 seconds.
# Fitting big fold 3 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12605	valid_1's rmse: 1.40865
# [400]	training's rmse: 0.789671	valid_1's rmse: 1.32192
# [600]	training's rmse: 0.582271	valid_1's rmse: 1.29935
# [800]	training's rmse: 0.440562	valid_1's rmse: 1.29305
# [1000]	training's rmse: 0.338081	valid_1's rmse: 1.2908
# [1200]	training's rmse: 0.266061	valid_1's rmse: 1.29001
# [1400]	training's rmse: 0.213253	valid_1's rmse: 1.28951
# [1600]	training's rmse: 0.173371	valid_1's rmse: 1.28939
# [1800]	training's rmse: 0.142849	valid_1's rmse: 1.28915
# [2000]	training's rmse: 0.119716	valid_1's rmse: 1.28898
# [2200]	training's rmse: 0.101595	valid_1's rmse: 1.28896
# Early stopping, best iteration is:
# [2094]	training's rmse: 0.11072	valid_1's rmse: 1.2889
# Model training done in 179.59001278877258 seconds.
# Fold error 1.2889034489278977
# Time passed: 2071.234126806259 seconds.
# Fitting big fold 3 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11854	valid_1's rmse: 1.44146
# [400]	training's rmse: 0.784932	valid_1's rmse: 1.35969
# [600]	training's rmse: 0.578922	valid_1's rmse: 1.33801
# [800]	training's rmse: 0.437875	valid_1's rmse: 1.33305
# [1000]	training's rmse: 0.336076	valid_1's rmse: 1.33084
# [1200]	training's rmse: 0.263886	valid_1's rmse: 1.33048
# Early stopping, best iteration is:
# [1149]	training's rmse: 0.280172	valid_1's rmse: 1.33027
# Model training done in 103.44700574874878 seconds.
# Fold error 1.330266623428018
# Time passed: 2179.953132390976 seconds.
# Average big fold 3 error: 1.3027305378344283
# Total big fold 3 std 0.03251
# Fitting big fold 4 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12692	valid_1's rmse: 1.41397
# [400]	training's rmse: 0.793834	valid_1's rmse: 1.33385
# [600]	training's rmse: 0.586458	valid_1's rmse: 1.31734
# [800]	training's rmse: 0.443506	valid_1's rmse: 1.31461
# [1000]	training's rmse: 0.339588	valid_1's rmse: 1.31346
# [1200]	training's rmse: 0.264168	valid_1's rmse: 1.31402
# Early stopping, best iteration is:
# [1023]	training's rmse: 0.329669	valid_1's rmse: 1.3134
# Model training done in 69.21800398826599 seconds.
# Fold error 1.3133980986351366
# Time passed: 2253.893137693405 seconds.
# Fitting big fold 4 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12291	valid_1's rmse: 1.41775
# [400]	training's rmse: 0.787379	valid_1's rmse: 1.33111
# [600]	training's rmse: 0.580755	valid_1's rmse: 1.31045
# [800]	training's rmse: 0.439408	valid_1's rmse: 1.30484
# [1000]	training's rmse: 0.33743	valid_1's rmse: 1.30402
# Early stopping, best iteration is:
# [943]	training's rmse: 0.363179	valid_1's rmse: 1.30383
# Model training done in 100.78301095962524 seconds.
# Fold error 1.303826232796415
# Time passed: 2359.139142513275 seconds.
# Fitting big fold 4 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12236	valid_1's rmse: 1.42275
# [400]	training's rmse: 0.788208	valid_1's rmse: 1.32603
# [600]	training's rmse: 0.582315	valid_1's rmse: 1.29984
# [800]	training's rmse: 0.441718	valid_1's rmse: 1.2906
# [1000]	training's rmse: 0.341328	valid_1's rmse: 1.28604
# [1200]	training's rmse: 0.268313	valid_1's rmse: 1.28496
# [1400]	training's rmse: 0.215292	valid_1's rmse: 1.28431
# [1600]	training's rmse: 0.174724	valid_1's rmse: 1.28364
# [1800]	training's rmse: 0.143773	valid_1's rmse: 1.28315
# [2000]	training's rmse: 0.119504	valid_1's rmse: 1.28291
# [2200]	training's rmse: 0.100606	valid_1's rmse: 1.2825
# [2400]	training's rmse: 0.0857742	valid_1's rmse: 1.28225
# [2600]	training's rmse: 0.07424	valid_1's rmse: 1.2821
# [2800]	training's rmse: 0.0653089	valid_1's rmse: 1.28205
# Early stopping, best iteration is:
# [2737]	training's rmse: 0.0679036	valid_1's rmse: 1.28201
# Model training done in 238.81194353103638 seconds.
# Fold error 1.2820130010426247
# Time passed: 2615.1303429603577 seconds.
# Fitting big fold 4 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12338	valid_1's rmse: 1.41498
# [400]	training's rmse: 0.78695	valid_1's rmse: 1.33073
# [600]	training's rmse: 0.579661	valid_1's rmse: 1.30914
# [800]	training's rmse: 0.438017	valid_1's rmse: 1.30431
# [1000]	training's rmse: 0.33637	valid_1's rmse: 1.30325
# [1200]	training's rmse: 0.26286	valid_1's rmse: 1.30252
# [1400]	training's rmse: 0.210048	valid_1's rmse: 1.3021
# [1600]	training's rmse: 0.170027	valid_1's rmse: 1.30136
# [1800]	training's rmse: 0.139097	valid_1's rmse: 1.30159
# Early stopping, best iteration is:
# [1614]	training's rmse: 0.167751	valid_1's rmse: 1.30127
# Model training done in 149.2656238079071 seconds.
# Fold error 1.3012651775904756
# Time passed: 2772.052223443985 seconds.
# Fitting big fold 4 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11919	valid_1's rmse: 1.43823
# [400]	training's rmse: 0.782006	valid_1's rmse: 1.36886
# [600]	training's rmse: 0.574263	valid_1's rmse: 1.35556
# [800]	training's rmse: 0.43285	valid_1's rmse: 1.35399
# [1000]	training's rmse: 0.332796	valid_1's rmse: 1.35312
# [1200]	training's rmse: 0.260057	valid_1's rmse: 1.35296
# Early stopping, best iteration is:
# [1084]	training's rmse: 0.299226	valid_1's rmse: 1.35266
# Model training done in 101.73437738418579 seconds.
# Fold error 1.3526636763734456
# Time passed: 2878.8178613185883 seconds.
# Average big fold 4 error: 1.3144786272393334
# Total big fold 4 std 0.02336
# Fitting big fold 5 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12942	valid_1's rmse: 1.42645
# [400]	training's rmse: 0.796429	valid_1's rmse: 1.34673
# [600]	training's rmse: 0.588583	valid_1's rmse: 1.32768
# [800]	training's rmse: 0.444596	valid_1's rmse: 1.32331
# [1000]	training's rmse: 0.340118	valid_1's rmse: 1.32316
# Early stopping, best iteration is:
# [885]	training's rmse: 0.39621	valid_1's rmse: 1.32275
# Model training done in 62.533103942871094 seconds.
# Fold error 1.3227486802961583
# Time passed: 2945.592841863632 seconds.
# Fitting big fold 5 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12378	valid_1's rmse: 1.38441
# [400]	training's rmse: 0.788396	valid_1's rmse: 1.29165
# [600]	training's rmse: 0.581209	valid_1's rmse: 1.26574
# [800]	training's rmse: 0.439794	valid_1's rmse: 1.25854
# [1000]	training's rmse: 0.338258	valid_1's rmse: 1.25594
# [1200]	training's rmse: 0.266053	valid_1's rmse: 1.25372
# [1400]	training's rmse: 0.213765	valid_1's rmse: 1.25251
# [1600]	training's rmse: 0.173876	valid_1's rmse: 1.25241
# [1800]	training's rmse: 0.142074	valid_1's rmse: 1.252
# Early stopping, best iteration is:
# [1721]	training's rmse: 0.153942	valid_1's rmse: 1.25183
# Model training done in 163.52901124954224 seconds.
# Fold error 1.251832787406284
# Time passed: 3117.8198499679565 seconds.
# Fitting big fold 5 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12315	valid_1's rmse: 1.39384
# [400]	training's rmse: 0.787822	valid_1's rmse: 1.3109
# [600]	training's rmse: 0.580906	valid_1's rmse: 1.29084
# [800]	training's rmse: 0.439324	valid_1's rmse: 1.28534
# [1000]	training's rmse: 0.337891	valid_1's rmse: 1.28461
# [1200]	training's rmse: 0.266798	valid_1's rmse: 1.28431
# [1400]	training's rmse: 0.214953	valid_1's rmse: 1.28451
# Early stopping, best iteration is:
# [1235]	training's rmse: 0.256997	valid_1's rmse: 1.28424
# Model training done in 120.96700763702393 seconds.
# Fold error 1.2842428482405095
# Time passed: 3244.5788576602936 seconds.
# Fitting big fold 5 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11524	valid_1's rmse: 1.46507
# [400]	training's rmse: 0.779892	valid_1's rmse: 1.39645
# [600]	training's rmse: 0.574048	valid_1's rmse: 1.38089
# [800]	training's rmse: 0.43486	valid_1's rmse: 1.3769
# [1000]	training's rmse: 0.334281	valid_1's rmse: 1.37594
# [1200]	training's rmse: 0.263544	valid_1's rmse: 1.3744
# [1400]	training's rmse: 0.212157	valid_1's rmse: 1.37364
# [1600]	training's rmse: 0.17223	valid_1's rmse: 1.37314
# [1800]	training's rmse: 0.14162	valid_1's rmse: 1.37324
# Early stopping, best iteration is:
# [1611]	training's rmse: 0.170439	valid_1's rmse: 1.3731
# Model training done in 141.94000816345215 seconds.
# Fold error 1.373104081131057
# Time passed: 3394.4758677482605 seconds.
# Fitting big fold 5 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12578	valid_1's rmse: 1.4031
# [400]	training's rmse: 0.790277	valid_1's rmse: 1.31304
# [600]	training's rmse: 0.583281	valid_1's rmse: 1.29245
# [800]	training's rmse: 0.440985	valid_1's rmse: 1.28774
# [1000]	training's rmse: 0.339191	valid_1's rmse: 1.28583
# [1200]	training's rmse: 0.266933	valid_1's rmse: 1.28569
# Early stopping, best iteration is:
# [1116]	training's rmse: 0.294531	valid_1's rmse: 1.28543
# Model training done in 100.30700540542603 seconds.
# Fold error 1.2854303127678923
# Time passed: 3500.0718715190887 seconds.
# Average big fold 5 error: 1.311987416815404
# Total big fold 5 std 0.04143
# Fitting big fold 6 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12434	valid_1's rmse: 1.42183
# [400]	training's rmse: 0.787896	valid_1's rmse: 1.34748
# [600]	training's rmse: 0.579597	valid_1's rmse: 1.33121
# [800]	training's rmse: 0.436893	valid_1's rmse: 1.32871
# [1000]	training's rmse: 0.334432	valid_1's rmse: 1.32753
# [1200]	training's rmse: 0.262194	valid_1's rmse: 1.32741
# [1400]	training's rmse: 0.208755	valid_1's rmse: 1.32721
# [1600]	training's rmse: 0.168422	valid_1's rmse: 1.32735
# Early stopping, best iteration is:
# [1401]	training's rmse: 0.2085	valid_1's rmse: 1.32719
# Model training done in 89.68100905418396 seconds.
# Fold error 1.327194046352534
# Time passed: 3595.782879590988 seconds.
# Fitting big fold 6 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12334	valid_1's rmse: 1.39027
# [400]	training's rmse: 0.788035	valid_1's rmse: 1.29115
# [600]	training's rmse: 0.581217	valid_1's rmse: 1.26646
# [800]	training's rmse: 0.439802	valid_1's rmse: 1.26089
# [1000]	training's rmse: 0.337985	valid_1's rmse: 1.25948
# [1200]	training's rmse: 0.265066	valid_1's rmse: 1.25836
# [1400]	training's rmse: 0.213319	valid_1's rmse: 1.25854
# Early stopping, best iteration is:
# [1283]	training's rmse: 0.241388	valid_1's rmse: 1.25819
# Model training done in 128.41100645065308 seconds.
# Fold error 1.2581886999970868
# Time passed: 3730.4368913173676 seconds.
# Fitting big fold 6 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12269	valid_1's rmse: 1.40742
# [400]	training's rmse: 0.787268	valid_1's rmse: 1.31538
# [600]	training's rmse: 0.580588	valid_1's rmse: 1.28996
# [800]	training's rmse: 0.439175	valid_1's rmse: 1.28211
# [1000]	training's rmse: 0.337565	valid_1's rmse: 1.2786
# [1200]	training's rmse: 0.26426	valid_1's rmse: 1.27769
# [1400]	training's rmse: 0.212437	valid_1's rmse: 1.27664
# [1600]	training's rmse: 0.172504	valid_1's rmse: 1.27602
# [1800]	training's rmse: 0.14125	valid_1's rmse: 1.27574
# [2000]	training's rmse: 0.117316	valid_1's rmse: 1.27551
# Early stopping, best iteration is:
# [1925]	training's rmse: 0.125551	valid_1's rmse: 1.27542
# Model training done in 175.3160102367401 seconds.
# Fold error 1.2754190038275417
# Time passed: 3915.8838999271393 seconds.
# Fitting big fold 6 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12572	valid_1's rmse: 1.39824
# [400]	training's rmse: 0.790247	valid_1's rmse: 1.30813
# [600]	training's rmse: 0.583825	valid_1's rmse: 1.28505
# [800]	training's rmse: 0.443131	valid_1's rmse: 1.27795
# [1000]	training's rmse: 0.341791	valid_1's rmse: 1.27537
# [1200]	training's rmse: 0.270301	valid_1's rmse: 1.27392
# [1400]	training's rmse: 0.217476	valid_1's rmse: 1.27355
# [1600]	training's rmse: 0.177334	valid_1's rmse: 1.27283
# [1800]	training's rmse: 0.146338	valid_1's rmse: 1.27273
# [2000]	training's rmse: 0.121961	valid_1's rmse: 1.27244
# [2200]	training's rmse: 0.103024	valid_1's rmse: 1.27213
# [2400]	training's rmse: 0.0885271	valid_1's rmse: 1.27188
# [2600]	training's rmse: 0.0774633	valid_1's rmse: 1.2717
# [2800]	training's rmse: 0.068501	valid_1's rmse: 1.27163
# [3000]	training's rmse: 0.0614081	valid_1's rmse: 1.27159
# [3200]	training's rmse: 0.0554561	valid_1's rmse: 1.27148
# Early stopping, best iteration is:
# [3191]	training's rmse: 0.0556992	valid_1's rmse: 1.27147
# Model training done in 256.6370167732239 seconds.
# Fold error 1.2714678640436103
# Time passed: 4192.86091542244 seconds.
# Fitting big fold 6 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11853	valid_1's rmse: 1.44238
# [400]	training's rmse: 0.784148	valid_1's rmse: 1.3584
# [600]	training's rmse: 0.577288	valid_1's rmse: 1.34211
# [800]	training's rmse: 0.436306	valid_1's rmse: 1.33668
# [1000]	training's rmse: 0.335101	valid_1's rmse: 1.33519
# [1200]	training's rmse: 0.262546	valid_1's rmse: 1.3339
# [1400]	training's rmse: 0.210114	valid_1's rmse: 1.33338
# [1600]	training's rmse: 0.169916	valid_1's rmse: 1.33272
# [1800]	training's rmse: 0.139094	valid_1's rmse: 1.33225
# [2000]	training's rmse: 0.114812	valid_1's rmse: 1.33225
# Early stopping, best iteration is:
# [1801]	training's rmse: 0.138985	valid_1's rmse: 1.33225
# Model training done in 150.44600796699524 seconds.
# Fold error 1.332246832839365
# Time passed: 4351.956925392151 seconds.
# Average big fold 6 error: 1.3057515641191872
# Total big fold 6 std 0.03064
# Fitting big fold 7 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.13092	valid_1's rmse: 1.40343
# [400]	training's rmse: 0.795229	valid_1's rmse: 1.31925
# [600]	training's rmse: 0.587303	valid_1's rmse: 1.29977
# [800]	training's rmse: 0.444557	valid_1's rmse: 1.29493
# [1000]	training's rmse: 0.341066	valid_1's rmse: 1.29317
# [1200]	training's rmse: 0.266319	valid_1's rmse: 1.29292
# [1400]	training's rmse: 0.212139	valid_1's rmse: 1.29342
# Early stopping, best iteration is:
# [1203]	training's rmse: 0.265395	valid_1's rmse: 1.29287
# Model training done in 79.23400354385376 seconds.
# Fold error 1.2928731565279858
# Time passed: 4436.455931425095 seconds.
# Fitting big fold 7 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12219	valid_1's rmse: 1.42413
# [400]	training's rmse: 0.788471	valid_1's rmse: 1.32647
# [600]	training's rmse: 0.58179	valid_1's rmse: 1.29691
# [800]	training's rmse: 0.439823	valid_1's rmse: 1.28711
# [1000]	training's rmse: 0.338426	valid_1's rmse: 1.28278
# [1200]	training's rmse: 0.265936	valid_1's rmse: 1.27997
# [1400]	training's rmse: 0.213703	valid_1's rmse: 1.27872
# [1600]	training's rmse: 0.174652	valid_1's rmse: 1.2781
# [1800]	training's rmse: 0.144514	valid_1's rmse: 1.27763
# [2000]	training's rmse: 0.120809	valid_1's rmse: 1.2774
# [2200]	training's rmse: 0.101698	valid_1's rmse: 1.2776
# Early stopping, best iteration is:
# [2105]	training's rmse: 0.110105	valid_1's rmse: 1.27731
# Model training done in 193.44301342964172 seconds.
# Fold error 1.2773148636748934
# Time passed: 4641.919946432114 seconds.
# Fitting big fold 7 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12657	valid_1's rmse: 1.35702
# [400]	training's rmse: 0.791051	valid_1's rmse: 1.27177
# [600]	training's rmse: 0.583002	valid_1's rmse: 1.25597
# [800]	training's rmse: 0.440848	valid_1's rmse: 1.2521
# [1000]	training's rmse: 0.33853	valid_1's rmse: 1.25247
# Early stopping, best iteration is:
# [829]	training's rmse: 0.424051	valid_1's rmse: 1.25165
# Model training done in 86.87100386619568 seconds.
# Fold error 1.2516534819425447
# Time passed: 4733.057950496674 seconds.
# Fitting big fold 7 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11943	valid_1's rmse: 1.43642
# [400]	training's rmse: 0.784398	valid_1's rmse: 1.35425
# [600]	training's rmse: 0.578379	valid_1's rmse: 1.33263
# [800]	training's rmse: 0.437881	valid_1's rmse: 1.32627
# [1000]	training's rmse: 0.336943	valid_1's rmse: 1.32421
# [1200]	training's rmse: 0.264125	valid_1's rmse: 1.32357
# [1400]	training's rmse: 0.211998	valid_1's rmse: 1.32376
# Early stopping, best iteration is:
# [1206]	training's rmse: 0.262317	valid_1's rmse: 1.32349
# Model training done in 112.64000797271729 seconds.
# Fold error 1.32349020139594
# Time passed: 4851.302957773209 seconds.
# Fitting big fold 7 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11856	valid_1's rmse: 1.44818
# [400]	training's rmse: 0.784584	valid_1's rmse: 1.36493
# [600]	training's rmse: 0.579316	valid_1's rmse: 1.34368
# [800]	training's rmse: 0.43933	valid_1's rmse: 1.33743
# [1000]	training's rmse: 0.338536	valid_1's rmse: 1.33462
# [1200]	training's rmse: 0.265529	valid_1's rmse: 1.33339
# [1400]	training's rmse: 0.213057	valid_1's rmse: 1.33323
# Early stopping, best iteration is:
# [1326]	training's rmse: 0.230816	valid_1's rmse: 1.33301
# Model training done in 116.1000063419342 seconds.
# Fold error 1.3330075996857047
# Time passed: 4973.596964359283 seconds.
# Average big fold 7 error: 1.2991397555757676
# Total big fold 7 std 0.02983
# Fitting big fold 8 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11326	valid_1's rmse: 1.44412
# [400]	training's rmse: 0.780297	valid_1's rmse: 1.36703
# [600]	training's rmse: 0.573903	valid_1's rmse: 1.34941
# [800]	training's rmse: 0.432414	valid_1's rmse: 1.34618
# [1000]	training's rmse: 0.330476	valid_1's rmse: 1.34541
# [1200]	training's rmse: 0.256082	valid_1's rmse: 1.34494
# [1400]	training's rmse: 0.201398	valid_1's rmse: 1.34482
# Early stopping, best iteration is:
# [1318]	training's rmse: 0.221638	valid_1's rmse: 1.34471
# Model training done in 85.3650062084198 seconds.
# Fold error 1.3447103023375546
# Time passed: 5064.577970027924 seconds.
# Fitting big fold 8 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.1248	valid_1's rmse: 1.39786
# [400]	training's rmse: 0.78895	valid_1's rmse: 1.30637
# [600]	training's rmse: 0.581104	valid_1's rmse: 1.27984
# [800]	training's rmse: 0.439062	valid_1's rmse: 1.27413
# [1000]	training's rmse: 0.337255	valid_1's rmse: 1.27414
# Early stopping, best iteration is:
# [903]	training's rmse: 0.382905	valid_1's rmse: 1.27346
# Model training done in 97.06300806999207 seconds.
# Fold error 1.2734608100214326
# Time passed: 5166.233975410461 seconds.
# Fitting big fold 8 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12651	valid_1's rmse: 1.37447
# [400]	training's rmse: 0.790441	valid_1's rmse: 1.29985
# [600]	training's rmse: 0.581973	valid_1's rmse: 1.28625
# [800]	training's rmse: 0.440092	valid_1's rmse: 1.2843
# [1000]	training's rmse: 0.338083	valid_1's rmse: 1.28387
# Early stopping, best iteration is:
# [919]	training's rmse: 0.375329	valid_1's rmse: 1.28351
# Model training done in 95.17001152038574 seconds.
# Fold error 1.2835088628920008
# Time passed: 5265.96498298645 seconds.
# Fitting big fold 8 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12172	valid_1's rmse: 1.41774
# [400]	training's rmse: 0.787368	valid_1's rmse: 1.3282
# [600]	training's rmse: 0.581438	valid_1's rmse: 1.30743
# [800]	training's rmse: 0.440367	valid_1's rmse: 1.30215
# [1000]	training's rmse: 0.338633	valid_1's rmse: 1.30092
# [1200]	training's rmse: 0.266014	valid_1's rmse: 1.30064
# [1400]	training's rmse: 0.214195	valid_1's rmse: 1.30107
# Early stopping, best iteration is:
# [1227]	training's rmse: 0.258425	valid_1's rmse: 1.30052
# Model training done in 116.05600571632385 seconds.
# Fold error 1.300515551580643
# Time passed: 5387.696991682053 seconds.
# Fitting big fold 8 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12402	valid_1's rmse: 1.40636
# [400]	training's rmse: 0.789097	valid_1's rmse: 1.32092
# [600]	training's rmse: 0.58227	valid_1's rmse: 1.29844
# [800]	training's rmse: 0.440738	valid_1's rmse: 1.2916
# [1000]	training's rmse: 0.339707	valid_1's rmse: 1.2888
# [1200]	training's rmse: 0.266898	valid_1's rmse: 1.28688
# [1400]	training's rmse: 0.213684	valid_1's rmse: 1.28598
# [1600]	training's rmse: 0.175175	valid_1's rmse: 1.28525
# [1800]	training's rmse: 0.144241	valid_1's rmse: 1.28454
# [2000]	training's rmse: 0.120497	valid_1's rmse: 1.28395
# [2200]	training's rmse: 0.102181	valid_1's rmse: 1.28356
# [2400]	training's rmse: 0.0878106	valid_1's rmse: 1.28315
# [2600]	training's rmse: 0.0764585	valid_1's rmse: 1.28287
# [2800]	training's rmse: 0.0670493	valid_1's rmse: 1.28271
# [3000]	training's rmse: 0.059806	valid_1's rmse: 1.28256
# [3200]	training's rmse: 0.05386	valid_1's rmse: 1.28252
# [3400]	training's rmse: 0.0488719	valid_1's rmse: 1.28246
# [3600]	training's rmse: 0.0448246	valid_1's rmse: 1.2824
# [3800]	training's rmse: 0.0414703	valid_1's rmse: 1.2824
# Early stopping, best iteration is:
# [3708]	training's rmse: 0.0429721	valid_1's rmse: 1.28237
# Model training done in 282.3320186138153 seconds.
# Fold error 1.282368530522367
# Time passed: 5693.637012004852 seconds.
# Average big fold 8 error: 1.3104600367932162
# Total big fold 8 std 0.02545
# Fitting big fold 9 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12063	valid_1's rmse: 1.433
# [400]	training's rmse: 0.786275	valid_1's rmse: 1.35814
# [600]	training's rmse: 0.57897	valid_1's rmse: 1.34249
# [800]	training's rmse: 0.436401	valid_1's rmse: 1.33828
# [1000]	training's rmse: 0.332938	valid_1's rmse: 1.33741
# [1200]	training's rmse: 0.257503	valid_1's rmse: 1.33673
# [1400]	training's rmse: 0.203008	valid_1's rmse: 1.33689
# Early stopping, best iteration is:
# [1260]	training's rmse: 0.239562	valid_1's rmse: 1.33658
# Model training done in 82.80100727081299 seconds.
# Fold error 1.336579411278092
# Time passed: 5781.731018066406 seconds.
# Fitting big fold 9 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12303	valid_1's rmse: 1.40999
# [400]	training's rmse: 0.786837	valid_1's rmse: 1.3308
# [600]	training's rmse: 0.579154	valid_1's rmse: 1.30993
# [800]	training's rmse: 0.438039	valid_1's rmse: 1.30441
# [1000]	training's rmse: 0.336819	valid_1's rmse: 1.30184
# [1200]	training's rmse: 0.264527	valid_1's rmse: 1.30172
# [1400]	training's rmse: 0.212374	valid_1's rmse: 1.30145
# [1600]	training's rmse: 0.171349	valid_1's rmse: 1.30109
# [1800]	training's rmse: 0.139858	valid_1's rmse: 1.30052
# [2000]	training's rmse: 0.11602	valid_1's rmse: 1.30039
# [2200]	training's rmse: 0.0975409	valid_1's rmse: 1.30031
# [2400]	training's rmse: 0.0833156	valid_1's rmse: 1.30021
# [2600]	training's rmse: 0.0723178	valid_1's rmse: 1.30018
# [2800]	training's rmse: 0.06395	valid_1's rmse: 1.30004
# Early stopping, best iteration is:
# [2760]	training's rmse: 0.0654746	valid_1's rmse: 1.3
# Model training done in 246.55501770973206 seconds.
# Fold error 1.2999975839880267
# Time passed: 6046.025030374527 seconds.
# Fitting big fold 9 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12268	valid_1's rmse: 1.40944
# [400]	training's rmse: 0.787298	valid_1's rmse: 1.32951
# [600]	training's rmse: 0.580551	valid_1's rmse: 1.30942
# [800]	training's rmse: 0.439598	valid_1's rmse: 1.3051
# [1000]	training's rmse: 0.337852	valid_1's rmse: 1.30229
# [1200]	training's rmse: 0.264991	valid_1's rmse: 1.30137
# [1400]	training's rmse: 0.213216	valid_1's rmse: 1.30029
# [1600]	training's rmse: 0.173157	valid_1's rmse: 1.29967
# [1800]	training's rmse: 0.141767	valid_1's rmse: 1.29951
# [2000]	training's rmse: 0.11719	valid_1's rmse: 1.29945
# Early stopping, best iteration is:
# [1943]	training's rmse: 0.123871	valid_1's rmse: 1.29931
# Model training done in 173.4720115661621 seconds.
# Fold error 1.2993116080935574
# Time passed: 6229.9660432338715 seconds.
# Fitting big fold 9 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.1203	valid_1's rmse: 1.43201
# [400]	training's rmse: 0.787598	valid_1's rmse: 1.34221
# [600]	training's rmse: 0.581656	valid_1's rmse: 1.32193
# [800]	training's rmse: 0.440661	valid_1's rmse: 1.31509
# [1000]	training's rmse: 0.339346	valid_1's rmse: 1.31474
# [1200]	training's rmse: 0.265984	valid_1's rmse: 1.3135
# [1400]	training's rmse: 0.214236	valid_1's rmse: 1.31306
# [1600]	training's rmse: 0.173005	valid_1's rmse: 1.31262
# [1800]	training's rmse: 0.141718	valid_1's rmse: 1.31242
# [2000]	training's rmse: 0.117871	valid_1's rmse: 1.31238
# [2200]	training's rmse: 0.0995809	valid_1's rmse: 1.31236
# Early stopping, best iteration is:
# [2073]	training's rmse: 0.110699	valid_1's rmse: 1.31226
# Model training done in 180.9300103187561 seconds.
# Fold error 1.3122597437463284
# Time passed: 6422.497055053711 seconds.
# Fitting big fold 9 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12599	valid_1's rmse: 1.387
# [400]	training's rmse: 0.789411	valid_1's rmse: 1.29695
# [600]	training's rmse: 0.581622	valid_1's rmse: 1.27651
# [800]	training's rmse: 0.438864	valid_1's rmse: 1.27223
# [1000]	training's rmse: 0.337827	valid_1's rmse: 1.2712
# [1200]	training's rmse: 0.266273	valid_1's rmse: 1.27122
# Early stopping, best iteration is:
# [1116]	training's rmse: 0.293255	valid_1's rmse: 1.27097
# Model training done in 102.61601066589355 seconds.
# Fold error 1.270974882309854
# Time passed: 6530.444060087204 seconds.
# Average big fold 9 error: 1.3111849863218583
# Total big fold 9 std 0.02125
# Fitting big fold 10 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12148	valid_1's rmse: 1.42139
# [400]	training's rmse: 0.787166	valid_1's rmse: 1.33486
# [600]	training's rmse: 0.578653	valid_1's rmse: 1.31471
# [800]	training's rmse: 0.434841	valid_1's rmse: 1.30895
# [1000]	training's rmse: 0.329896	valid_1's rmse: 1.30779
# [1200]	training's rmse: 0.25434	valid_1's rmse: 1.30735
# [1400]	training's rmse: 0.199727	valid_1's rmse: 1.30711
# [1600]	training's rmse: 0.158685	valid_1's rmse: 1.30698
# Early stopping, best iteration is:
# [1463]	training's rmse: 0.185405	valid_1's rmse: 1.30693
# Model training done in 92.74000597000122 seconds.
# Fold error 1.3069259790915422
# Time passed: 6629.252067089081 seconds.
# Fitting big fold 10 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12811	valid_1's rmse: 1.3312
# [400]	training's rmse: 0.791855	valid_1's rmse: 1.24058
# [600]	training's rmse: 0.58393	valid_1's rmse: 1.22153
# [800]	training's rmse: 0.441724	valid_1's rmse: 1.21779
# [1000]	training's rmse: 0.340781	valid_1's rmse: 1.21598
# [1200]	training's rmse: 0.266519	valid_1's rmse: 1.21463
# [1400]	training's rmse: 0.212113	valid_1's rmse: 1.21391
# [1600]	training's rmse: 0.172017	valid_1's rmse: 1.21334
# Early stopping, best iteration is:
# [1595]	training's rmse: 0.172935	valid_1's rmse: 1.21333
# Model training done in 154.15700817108154 seconds.
# Fold error 1.2133258989138787
# Time passed: 6791.358080863953 seconds.
# Fitting big fold 10 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12575	valid_1's rmse: 1.39312
# [400]	training's rmse: 0.790118	valid_1's rmse: 1.30934
# [600]	training's rmse: 0.583086	valid_1's rmse: 1.28956
# [800]	training's rmse: 0.441278	valid_1's rmse: 1.2841
# [1000]	training's rmse: 0.339694	valid_1's rmse: 1.28007
# [1200]	training's rmse: 0.267277	valid_1's rmse: 1.27887
# [1400]	training's rmse: 0.213987	valid_1's rmse: 1.27826
# [1600]	training's rmse: 0.174482	valid_1's rmse: 1.27801
# Early stopping, best iteration is:
# [1580]	training's rmse: 0.177977	valid_1's rmse: 1.27792
# Model training done in 146.89700984954834 seconds.
# Fold error 1.2779171255156914
# Time passed: 6945.90208697319 seconds.
# Fitting big fold 10 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12052	valid_1's rmse: 1.44315
# [400]	training's rmse: 0.785594	valid_1's rmse: 1.37036
# [600]	training's rmse: 0.579851	valid_1's rmse: 1.35451
# [800]	training's rmse: 0.439148	valid_1's rmse: 1.34867
# [1000]	training's rmse: 0.337786	valid_1's rmse: 1.34636
# [1200]	training's rmse: 0.264754	valid_1's rmse: 1.34563
# Early stopping, best iteration is:
# [1130]	training's rmse: 0.287237	valid_1's rmse: 1.34543
# Model training done in 111.47583603858948 seconds.
# Fold error 1.345426785558299
# Time passed: 7062.744673728943 seconds.
# Fitting big fold 10 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11835	valid_1's rmse: 1.4485
# [400]	training's rmse: 0.786382	valid_1's rmse: 1.35982
# [600]	training's rmse: 0.580096	valid_1's rmse: 1.33794
# [800]	training's rmse: 0.439093	valid_1's rmse: 1.33182
# [1000]	training's rmse: 0.338726	valid_1's rmse: 1.32899
# [1200]	training's rmse: 0.266509	valid_1's rmse: 1.32815
# [1400]	training's rmse: 0.213292	valid_1's rmse: 1.32778
# [1600]	training's rmse: 0.173014	valid_1's rmse: 1.32759
# [1800]	training's rmse: 0.142478	valid_1's rmse: 1.32745
# Early stopping, best iteration is:
# [1796]	training's rmse: 0.143042	valid_1's rmse: 1.32745
# Model training done in 156.05802154541016 seconds.
# Fold error 1.3274502819475305
# Time passed: 7227.399333000183 seconds.
# Average big fold 10 error: 1.3047183607724537
# Total big fold 10 std 0.04625
# Fitting big fold 11 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12018	valid_1's rmse: 1.43851
# [400]	training's rmse: 0.787323	valid_1's rmse: 1.35497
# [600]	training's rmse: 0.580957	valid_1's rmse: 1.33475
# [800]	training's rmse: 0.438946	valid_1's rmse: 1.33
# [1000]	training's rmse: 0.335547	valid_1's rmse: 1.32944
# Early stopping, best iteration is:
# [974]	training's rmse: 0.347283	valid_1's rmse: 1.32927
# Model training done in 67.08000707626343 seconds.
# Fold error 1.329270216950129
# Time passed: 7298.998335599899 seconds.
# Fitting big fold 11 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12624	valid_1's rmse: 1.35537
# [400]	training's rmse: 0.78838	valid_1's rmse: 1.28629
# [600]	training's rmse: 0.580459	valid_1's rmse: 1.27484
# [800]	training's rmse: 0.43807	valid_1's rmse: 1.27183
# [1000]	training's rmse: 0.337015	valid_1's rmse: 1.27091
# [1200]	training's rmse: 0.263187	valid_1's rmse: 1.26972
# [1400]	training's rmse: 0.210697	valid_1's rmse: 1.26832
# [1600]	training's rmse: 0.170795	valid_1's rmse: 1.26739
# [1800]	training's rmse: 0.1403	valid_1's rmse: 1.26723
# [2000]	training's rmse: 0.116516	valid_1's rmse: 1.26716
# [2200]	training's rmse: 0.0977578	valid_1's rmse: 1.26701
# [2400]	training's rmse: 0.0833586	valid_1's rmse: 1.26671
# [2600]	training's rmse: 0.071911	valid_1's rmse: 1.26651
# [2800]	training's rmse: 0.0627888	valid_1's rmse: 1.26628
# [3000]	training's rmse: 0.0557495	valid_1's rmse: 1.26617
# [3200]	training's rmse: 0.0499502	valid_1's rmse: 1.26606
# [3400]	training's rmse: 0.0452435	valid_1's rmse: 1.26598
# [3600]	training's rmse: 0.0412878	valid_1's rmse: 1.26589
# [3800]	training's rmse: 0.0379924	valid_1's rmse: 1.26586
# [4000]	training's rmse: 0.0350476	valid_1's rmse: 1.26586
# Early stopping, best iteration is:
# [3809]	training's rmse: 0.0378618	valid_1's rmse: 1.26584
# Model training done in 325.45402336120605 seconds.
# Fold error 1.2658448331260506
# Time passed: 7650.632356882095 seconds.
# Fitting big fold 11 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12444	valid_1's rmse: 1.39582
# [400]	training's rmse: 0.789696	valid_1's rmse: 1.29958
# [600]	training's rmse: 0.583787	valid_1's rmse: 1.2753
# [800]	training's rmse: 0.44275	valid_1's rmse: 1.2667
# [1000]	training's rmse: 0.340359	valid_1's rmse: 1.26386
# Early stopping, best iteration is:
# [977]	training's rmse: 0.350705	valid_1's rmse: 1.26356
# Model training done in 98.71201157569885 seconds.
# Fold error 1.263561920123151
# Time passed: 7754.011365652084 seconds.
# Fitting big fold 11 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12266	valid_1's rmse: 1.40765
# [400]	training's rmse: 0.787802	valid_1's rmse: 1.32873
# [600]	training's rmse: 0.580843	valid_1's rmse: 1.31031
# [800]	training's rmse: 0.440075	valid_1's rmse: 1.3072
# [1000]	training's rmse: 0.338903	valid_1's rmse: 1.30609
# [1200]	training's rmse: 0.26674	valid_1's rmse: 1.30614
# Early stopping, best iteration is:
# [1098]	training's rmse: 0.30015	valid_1's rmse: 1.30588
# Model training done in 105.56100559234619 seconds.
# Fold error 1.3058788483637718
# Time passed: 7864.538373470306 seconds.
# Fitting big fold 11 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11885	valid_1's rmse: 1.44534
# [400]	training's rmse: 0.783358	valid_1's rmse: 1.36883
# [600]	training's rmse: 0.576985	valid_1's rmse: 1.35183
# [800]	training's rmse: 0.436446	valid_1's rmse: 1.3484
# [1000]	training's rmse: 0.336111	valid_1's rmse: 1.34653
# [1200]	training's rmse: 0.264265	valid_1's rmse: 1.34591
# [1400]	training's rmse: 0.21117	valid_1's rmse: 1.34597
# Early stopping, best iteration is:
# [1285]	training's rmse: 0.240157	valid_1's rmse: 1.34577
# Model training done in 113.2380051612854 seconds.
# Fold error 1.3457725071219946
# Time passed: 7983.514377832413 seconds.
# Average big fold 11 error: 1.3139064246760694
# Total big fold 11 std 0.03304
# Fitting big fold 12 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.13645	valid_1's rmse: 1.40835
# [400]	training's rmse: 0.802609	valid_1's rmse: 1.31834
# [600]	training's rmse: 0.594169	valid_1's rmse: 1.29361
# [800]	training's rmse: 0.450426	valid_1's rmse: 1.28711
# [1000]	training's rmse: 0.346692	valid_1's rmse: 1.28415
# [1200]	training's rmse: 0.271642	valid_1's rmse: 1.28304
# [1400]	training's rmse: 0.216873	valid_1's rmse: 1.28266
# [1600]	training's rmse: 0.176657	valid_1's rmse: 1.28231
# [1800]	training's rmse: 0.145595	valid_1's rmse: 1.2826
# Early stopping, best iteration is:
# [1619]	training's rmse: 0.173287	valid_1's rmse: 1.28227
# Model training done in 103.53500390052795 seconds.
# Fold error 1.2822723712134774
# Time passed: 8093.758386135101 seconds.
# Fitting big fold 12 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11895	valid_1's rmse: 1.43179
# [400]	training's rmse: 0.784322	valid_1's rmse: 1.34989
# [600]	training's rmse: 0.577666	valid_1's rmse: 1.33612
# [800]	training's rmse: 0.43628	valid_1's rmse: 1.33306
# Early stopping, best iteration is:
# [787]	training's rmse: 0.444116	valid_1's rmse: 1.33285
# Model training done in 87.52301096916199 seconds.
# Fold error 1.3328506352411924
# Time passed: 8185.1993932724 seconds.
# Fitting big fold 12 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12248	valid_1's rmse: 1.40468
# [400]	training's rmse: 0.78501	valid_1's rmse: 1.324
# [600]	training's rmse: 0.577567	valid_1's rmse: 1.30554
# [800]	training's rmse: 0.43611	valid_1's rmse: 1.30118
# [1000]	training's rmse: 0.33473	valid_1's rmse: 1.2995
# [1200]	training's rmse: 0.262342	valid_1's rmse: 1.29922
# Early stopping, best iteration is:
# [1154]	training's rmse: 0.276616	valid_1's rmse: 1.2991
# Model training done in 113.87300539016724 seconds.
# Fold error 1.2990993933811013
# Time passed: 8304.18939948082 seconds.
# Fitting big fold 12 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12364	valid_1's rmse: 1.40647
# [400]	training's rmse: 0.786955	valid_1's rmse: 1.3274
# [600]	training's rmse: 0.579592	valid_1's rmse: 1.30855
# [800]	training's rmse: 0.438361	valid_1's rmse: 1.30437
# [1000]	training's rmse: 0.335931	valid_1's rmse: 1.30375
# Early stopping, best iteration is:
# [952]	training's rmse: 0.358029	valid_1's rmse: 1.3035
# Model training done in 93.71400547027588 seconds.
# Fold error 1.303498126984296
# Time passed: 8402.289404153824 seconds.
# Fitting big fold 12 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11605	valid_1's rmse: 1.45252
# [400]	training's rmse: 0.78204	valid_1's rmse: 1.37278
# [600]	training's rmse: 0.577016	valid_1's rmse: 1.35429
# [800]	training's rmse: 0.436833	valid_1's rmse: 1.34975
# ...
# [200]	training's rmse: 1.11742	valid_1's rmse: 1.45493
# [400]	training's rmse: 0.780464	valid_1's rmse: 1.38229
# [600]	training's rmse: 0.57488	valid_1's rmse: 1.36716
# [800]	training's rmse: 0.434833	valid_1's rmse: 1.36151
# [1000]	training's rmse: 0.335066	valid_1's rmse: 1.35832
# [1200]	training's rmse: 0.262516	valid_1's rmse: 1.35718
# [1400]	training's rmse: 0.210999	valid_1's rmse: 1.35567
# [1600]	training's rmse: 0.172642	valid_1's rmse: 1.35553
# [1800]	training's rmse: 0.142438	valid_1's rmse: 1.35529
# [2000]	training's rmse: 0.118585	valid_1's rmse: 1.35496
# [2200]	training's rmse: 0.0999045	valid_1's rmse: 1.35482
# [2400]	training's rmse: 0.0854489	valid_1's rmse: 1.35456
# [2600]	training's rmse: 0.0739775	valid_1's rmse: 1.35455
# [2800]	training's rmse: 0.0647819	valid_1's rmse: 1.3544
# [3000]	training's rmse: 0.0573682	valid_1's rmse: 1.35444
# Early stopping, best iteration is:
# [2832]	training's rmse: 0.0635257	valid_1's rmse: 1.35437
# Model training done in 248.90101528167725 seconds.
# Fold error 1.354369857380502
# Time passed: 11515.908035039902 seconds.
# Fitting big fold 17 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11629	valid_1's rmse: 1.46022
# [400]	training's rmse: 0.78162	valid_1's rmse: 1.37248
# [600]	training's rmse: 0.575449	valid_1's rmse: 1.35173
# [800]	training's rmse: 0.43425	valid_1's rmse: 1.34822
# [1000]	training's rmse: 0.33332	valid_1's rmse: 1.34799
# Early stopping, best iteration is:
# [979]	training's rmse: 0.342562	valid_1's rmse: 1.34779
# Model training done in 100.05085182189941 seconds.
# Fold error 1.3477860604873484
# Time passed: 11620.875889539719 seconds.
# Fitting big fold 17 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.1197	valid_1's rmse: 1.43305
# [400]	training's rmse: 0.786188	valid_1's rmse: 1.33971
# [600]	training's rmse: 0.580387	valid_1's rmse: 1.31843
# [800]	training's rmse: 0.439941	valid_1's rmse: 1.31344
# [1000]	training's rmse: 0.338949	valid_1's rmse: 1.31131
# [1200]	training's rmse: 0.267603	valid_1's rmse: 1.31107
# Early stopping, best iteration is:
# [1132]	training's rmse: 0.289054	valid_1's rmse: 1.3109
# Model training done in 108.43928170204163 seconds.
# Fold error 1.3109001176765824
# Time passed: 11734.844178676605 seconds.
# Fitting big fold 17 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12734	valid_1's rmse: 1.39476
# [400]	training's rmse: 0.791201	valid_1's rmse: 1.30574
# [600]	training's rmse: 0.583658	valid_1's rmse: 1.2827
# [800]	training's rmse: 0.441521	valid_1's rmse: 1.27702
# [1000]	training's rmse: 0.338713	valid_1's rmse: 1.27475
# [1200]	training's rmse: 0.266071	valid_1's rmse: 1.27365
# [1400]	training's rmse: 0.213241	valid_1's rmse: 1.27325
# [1600]	training's rmse: 0.172513	valid_1's rmse: 1.27289
# [1800]	training's rmse: 0.141368	valid_1's rmse: 1.27271
# Early stopping, best iteration is:
# [1797]	training's rmse: 0.141783	valid_1's rmse: 1.2727
# Model training done in 151.52474522590637 seconds.
# Fold error 1.272704581910965
# Time passed: 11895.361924886703 seconds.
# Average big fold 17 error: 1.3028057218051616
# Total big fold 17 std 0.03252
# Fitting big fold 18 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12923	valid_1's rmse: 1.41896
# [400]	training's rmse: 0.792793	valid_1's rmse: 1.33521
# [600]	training's rmse: 0.58418	valid_1's rmse: 1.31377
# [800]	training's rmse: 0.441165	valid_1's rmse: 1.3074
# [1000]	training's rmse: 0.338224	valid_1's rmse: 1.30475
# [1200]	training's rmse: 0.263705	valid_1's rmse: 1.3042
# [1400]	training's rmse: 0.208543	valid_1's rmse: 1.3043
# Early stopping, best iteration is:
# [1311]	training's rmse: 0.231074	valid_1's rmse: 1.30401
# Model training done in 84.49100089073181 seconds.
# Fold error 1.3040133682343682
# Time passed: 11985.600928783417 seconds.
# Fitting big fold 18 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12449	valid_1's rmse: 1.38981
# [400]	training's rmse: 0.788078	valid_1's rmse: 1.29997
# [600]	training's rmse: 0.581659	valid_1's rmse: 1.27514
# [800]	training's rmse: 0.440107	valid_1's rmse: 1.26675
# [1000]	training's rmse: 0.338249	valid_1's rmse: 1.26353
# [1200]	training's rmse: 0.265613	valid_1's rmse: 1.26298
# [1400]	training's rmse: 0.21391	valid_1's rmse: 1.2622
# [1600]	training's rmse: 0.175067	valid_1's rmse: 1.26169
# [1800]	training's rmse: 0.144534	valid_1's rmse: 1.26156
# Early stopping, best iteration is:
# [1698]	training's rmse: 0.158849	valid_1's rmse: 1.26135
# Model training done in 162.31391024589539 seconds.
# Fold error 1.2613468263838397
# Time passed: 12158.93499493599 seconds.
# Fitting big fold 18 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.118	valid_1's rmse: 1.45679
# [400]	training's rmse: 0.782435	valid_1's rmse: 1.38732
# [600]	training's rmse: 0.575947	valid_1's rmse: 1.37356
# [800]	training's rmse: 0.43587	valid_1's rmse: 1.37235
# Early stopping, best iteration is:
# [686]	training's rmse: 0.509805	valid_1's rmse: 1.37166
# Model training done in 95.50925636291504 seconds.
# Fold error 1.3716629920282344
# Time passed: 12259.395286560059 seconds.
# Fitting big fold 18 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12479	valid_1's rmse: 1.41356
# [400]	training's rmse: 0.79087	valid_1's rmse: 1.32363
# [600]	training's rmse: 0.584747	valid_1's rmse: 1.2999
# [800]	training's rmse: 0.444011	valid_1's rmse: 1.29373
# [1000]	training's rmse: 0.342959	valid_1's rmse: 1.29078
# [1200]	training's rmse: 0.270044	valid_1's rmse: 1.28946
# [1400]	training's rmse: 0.21861	valid_1's rmse: 1.2885
# [1600]	training's rmse: 0.17968	valid_1's rmse: 1.28806
# [1800]	training's rmse: 0.148687	valid_1's rmse: 1.28808
# Early stopping, best iteration is:
# [1755]	training's rmse: 0.154785	valid_1's rmse: 1.28801
# Model training done in 186.32501578330994 seconds.
# Fold error 1.2880076612598483
# Time passed: 12459.709913015366 seconds.
# Fitting big fold 18 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12159	valid_1's rmse: 1.41394
# [400]	training's rmse: 0.786748	valid_1's rmse: 1.32954
# [600]	training's rmse: 0.579463	valid_1's rmse: 1.3081
# [800]	training's rmse: 0.437204	valid_1's rmse: 1.3046
# [1000]	training's rmse: 0.334131	valid_1's rmse: 1.30266
# Early stopping, best iteration is:
# [988]	training's rmse: 0.33948	valid_1's rmse: 1.3026
# Model training done in 103.43954849243164 seconds.
# Fold error 1.3026047685827555
# Time passed: 12568.481334209442 seconds.
# Average big fold 18 error: 1.305697887846329
# Total big fold 18 std 0.03645
# Fitting big fold 19 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12696	valid_1's rmse: 1.42908
# [400]	training's rmse: 0.796858	valid_1's rmse: 1.33874
# [600]	training's rmse: 0.590074	valid_1's rmse: 1.31562
# [800]	training's rmse: 0.44702	valid_1's rmse: 1.3077
# [1000]	training's rmse: 0.343231	valid_1's rmse: 1.30555
# [1200]	training's rmse: 0.26954	valid_1's rmse: 1.30453
# [1400]	training's rmse: 0.214086	valid_1's rmse: 1.30454
# Early stopping, best iteration is:
# [1215]	training's rmse: 0.264933	valid_1's rmse: 1.30442
# Model training done in 89.26453042030334 seconds.
# Fold error 1.304419563613379
# Time passed: 12663.731585979462 seconds.
# Fitting big fold 19 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12486	valid_1's rmse: 1.35901
# [400]	training's rmse: 0.789505	valid_1's rmse: 1.26154
# [600]	training's rmse: 0.58158	valid_1's rmse: 1.23971
# [800]	training's rmse: 0.440119	valid_1's rmse: 1.23394
# [1000]	training's rmse: 0.339574	valid_1's rmse: 1.23238
# [1200]	training's rmse: 0.268971	valid_1's rmse: 1.23134
# [1400]	training's rmse: 0.216843	valid_1's rmse: 1.23086
# [1600]	training's rmse: 0.176312	valid_1's rmse: 1.23058
# [1800]	training's rmse: 0.145497	valid_1's rmse: 1.23029
# [2000]	training's rmse: 0.121455	valid_1's rmse: 1.23025
# Early stopping, best iteration is:
# [1946]	training's rmse: 0.127435	valid_1's rmse: 1.23009
# Model training done in 207.85413312911987 seconds.
# Fold error 1.2300866453578965
# Time passed: 12884.11716413498 seconds.
# Fitting big fold 19 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.1182	valid_1's rmse: 1.4405
# [400]	training's rmse: 0.782468	valid_1's rmse: 1.36012
# [600]	training's rmse: 0.576727	valid_1's rmse: 1.33913
# [800]	training's rmse: 0.436112	valid_1's rmse: 1.33597
# [1000]	training's rmse: 0.335355	valid_1's rmse: 1.3356
# [1200]	training's rmse: 0.26252	valid_1's rmse: 1.3355
# Early stopping, best iteration is:
# [1156]	training's rmse: 0.275874	valid_1's rmse: 1.33502
# Model training done in 117.02631855010986 seconds.
# Fold error 1.335017397455523
# Time passed: 13007.2466776371 seconds.
# Fitting big fold 19 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12167	valid_1's rmse: 1.41816
# [400]	training's rmse: 0.784793	valid_1's rmse: 1.35102
# [600]	training's rmse: 0.578188	valid_1's rmse: 1.33607
# [800]	training's rmse: 0.436797	valid_1's rmse: 1.33348
# [1000]	training's rmse: 0.336201	valid_1's rmse: 1.33219
# [1200]	training's rmse: 0.26301	valid_1's rmse: 1.33158
# [1400]	training's rmse: 0.210423	valid_1's rmse: 1.33117
# [1600]	training's rmse: 0.169373	valid_1's rmse: 1.33083
# [1800]	training's rmse: 0.138198	valid_1's rmse: 1.33059
# [2000]	training's rmse: 0.11416	valid_1's rmse: 1.33018
# [2200]	training's rmse: 0.0958895	valid_1's rmse: 1.32995
# [2400]	training's rmse: 0.0818441	valid_1's rmse: 1.32984
# [2600]	training's rmse: 0.0711935	valid_1's rmse: 1.32986
# Early stopping, best iteration is:
# [2475]	training's rmse: 0.0775373	valid_1's rmse: 1.32979
# Model training done in 234.29865884780884 seconds.
# Fold error 1.329790216312841
# Time passed: 13257.673856973648 seconds.
# Fitting big fold 19 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12169	valid_1's rmse: 1.42029
# [400]	training's rmse: 0.784577	valid_1's rmse: 1.34632
# [600]	training's rmse: 0.577168	valid_1's rmse: 1.32999
# [800]	training's rmse: 0.436391	valid_1's rmse: 1.32609
# [1000]	training's rmse: 0.33479	valid_1's rmse: 1.32629
# Early stopping, best iteration is:
# [824]	training's rmse: 0.422492	valid_1's rmse: 1.32587
# Model training done in 84.08325290679932 seconds.
# Fold error 1.3258663269492026
# Time passed: 13346.259292840958 seconds.
# Average big fold 19 error: 1.3094560115408578
# Total big fold 19 std 0.03889
# Fitting big fold 20 out of 20 and sub fold 1 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12597	valid_1's rmse: 1.423
# [400]	training's rmse: 0.792648	valid_1's rmse: 1.34141
# [600]	training's rmse: 0.585644	valid_1's rmse: 1.32285
# [800]	training's rmse: 0.442058	valid_1's rmse: 1.31713
# [1000]	training's rmse: 0.338459	valid_1's rmse: 1.31446
# [1200]	training's rmse: 0.26305	valid_1's rmse: 1.31325
# [1400]	training's rmse: 0.208587	valid_1's rmse: 1.3123
# [1600]	training's rmse: 0.168174	valid_1's rmse: 1.31185
# [1800]	training's rmse: 0.137445	valid_1's rmse: 1.31174
# [2000]	training's rmse: 0.113967	valid_1's rmse: 1.31167
# Early stopping, best iteration is:
# [1964]	training's rmse: 0.117879	valid_1's rmse: 1.31161
# Model training done in 129.917387008667 seconds.
# Fold error 1.3116123794161936
# Time passed: 13486.13647890091 seconds.
# Fitting big fold 20 out of 20 and sub fold 2 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12088	valid_1's rmse: 1.43161
# [400]	training's rmse: 0.784578	valid_1's rmse: 1.36026
# [600]	training's rmse: 0.578446	valid_1's rmse: 1.34332
# [800]	training's rmse: 0.437865	valid_1's rmse: 1.33869
# [1000]	training's rmse: 0.337454	valid_1's rmse: 1.33654
# [1200]	training's rmse: 0.265673	valid_1's rmse: 1.33495
# [1400]	training's rmse: 0.213309	valid_1's rmse: 1.33454
# [1600]	training's rmse: 0.17419	valid_1's rmse: 1.33445
# Early stopping, best iteration is:
# [1570]	training's rmse: 0.179853	valid_1's rmse: 1.33434
# Model training done in 176.3153998851776 seconds.
# Fold error 1.3343430356479788
# Time passed: 13671.698827981949 seconds.
# Fitting big fold 20 out of 20 and sub fold 3 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12499	valid_1's rmse: 1.39742
# [400]	training's rmse: 0.789645	valid_1's rmse: 1.30226
# [600]	training's rmse: 0.582593	valid_1's rmse: 1.27848
# [800]	training's rmse: 0.441323	valid_1's rmse: 1.27145
# [1000]	training's rmse: 0.340864	valid_1's rmse: 1.26906
# [1200]	training's rmse: 0.27001	valid_1's rmse: 1.26753
# [1400]	training's rmse: 0.217651	valid_1's rmse: 1.2661
# [1600]	training's rmse: 0.17728	valid_1's rmse: 1.26598
# [1800]	training's rmse: 0.145348	valid_1's rmse: 1.26593
# Early stopping, best iteration is:
# [1722]	training's rmse: 0.156854	valid_1's rmse: 1.26587
# Model training done in 182.2749252319336 seconds.
# Fold error 1.2658686622947
# Time passed: 13864.281899690628 seconds.
# Fitting big fold 20 out of 20 and sub fold 4 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.11983	valid_1's rmse: 1.4319
# [400]	training's rmse: 0.785263	valid_1's rmse: 1.34567
# [600]	training's rmse: 0.578389	valid_1's rmse: 1.3241
# [800]	training's rmse: 0.436785	valid_1's rmse: 1.31732
# [1000]	training's rmse: 0.335119	valid_1's rmse: 1.31545
# [1200]	training's rmse: 0.260942	valid_1's rmse: 1.31474
# [1400]	training's rmse: 0.208518	valid_1's rmse: 1.31374
# [1600]	training's rmse: 0.168346	valid_1's rmse: 1.31311
# [1800]	training's rmse: 0.137239	valid_1's rmse: 1.31262
# [2000]	training's rmse: 0.112478	valid_1's rmse: 1.31245
# [2200]	training's rmse: 0.0932763	valid_1's rmse: 1.31214
# [2400]	training's rmse: 0.0786001	valid_1's rmse: 1.31207
# [2600]	training's rmse: 0.0669954	valid_1's rmse: 1.31169
# [2800]	training's rmse: 0.0579245	valid_1's rmse: 1.31158
# [3000]	training's rmse: 0.0507542	valid_1's rmse: 1.31148
# [3200]	training's rmse: 0.0449794	valid_1's rmse: 1.31139
# [3400]	training's rmse: 0.0403601	valid_1's rmse: 1.31128
# [3600]	training's rmse: 0.0364976	valid_1's rmse: 1.31119
# [3800]	training's rmse: 0.0332924	valid_1's rmse: 1.31111
# [4000]	training's rmse: 0.0304676	valid_1's rmse: 1.31106
# [4200]	training's rmse: 0.0280028	valid_1's rmse: 1.31106
# [4400]	training's rmse: 0.0259141	valid_1's rmse: 1.31102
# [4600]	training's rmse: 0.0240718	valid_1's rmse: 1.31099
# [4800]	training's rmse: 0.0224621	valid_1's rmse: 1.31096
# [5000]	training's rmse: 0.02097	valid_1's rmse: 1.31097
# [5200]	training's rmse: 0.0196741	valid_1's rmse: 1.31096
# Early stopping, best iteration is:
# [5057]	training's rmse: 0.020586	valid_1's rmse: 1.31095
# Model training done in 465.6993873119354 seconds.
# Fold error 1.3109520858309747
# Time passed: 14365.925522089005 seconds.
# Fitting big fold 20 out of 20 and sub fold 5 out of 5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's rmse: 1.12523	valid_1's rmse: 1.40297
# [400]	training's rmse: 0.788865	valid_1's rmse: 1.32096
# [600]	training's rmse: 0.581997	valid_1's rmse: 1.30199
# [800]	training's rmse: 0.440043	valid_1's rmse: 1.2971
# [1000]	training's rmse: 0.33845	valid_1's rmse: 1.29705
# [1200]	training's rmse: 0.26562	valid_1's rmse: 1.29727
# Early stopping, best iteration is:
# [1010]	training's rmse: 0.33398	valid_1's rmse: 1.29688
# Model training done in 107.06634211540222 seconds.
# Fold error 1.2968783903001133
# Time passed: 14478.261620283127 seconds.
# Average big fold 20 error: 1.3052389435350589
# Total big fold 20 std 0.0225
# Wall time: 4h 1min 18s

# %%
# %%time
avg_error = np.mean(([np.mean(x) for x in fold_errors]))
avg_std = np.std(([np.mean (x) for x in fold_errors]))
print(f'Average error across 20 folds: {avg_error.round(5)}')
print(f'Average std across 20 folds: {avg_std.round(5)}')
print(f'(averaged std of 20 folds: {np.mean(([np.std (x) for x in fold_errors])).round(5)})')
# Out:
# Average error across 20 folds: 1.3028
# Average std across 20 folds: 0.00698
# (averaged std of 20 folds: 0.03007)
# Wall time: 3.5 ms

# %%
len(y_oof_lgb), len(avg_test_pred_20), len(fold_errors)
# Out:
# (20, 20, 20)

# %%
print('Length of test predictions:', len(avg_test_pred_20))
avg_pred_test_list_lgb = np.mean(avg_test_pred_20, axis=0)
print('Length of avg test predictions:', len(avg_pred_test_list_lgb))
# Out:
# Length of test predictions: 20
# Length of avg test predictions: 49342

# %%
pd.DataFrame(fold_errors).to_csv(f'{PRED_TRAIN_PATH}{MODEL_NAME}_fold_errors_cv{avg_error*1000:0>4.0f}_std{avg_std*1000:0>4.0f}.csv',
                                 index=False, header=False)

# %% [markdown]
# # 5.Stacking/Blending - TBA

# %% [markdown]
# # 6. Save results and prepare model for submitting

# %%
# %%time
# 20x oof train preds
with open(f'{PRED_TRAIN_PATH}{MODEL_NAME}_20folds_train_cv{avg_error*1000:0>4.0f}_std{avg_std*1000:0>4.0f}.pkl', 'wb') as f:
    pickle.dump(y_oof_lgb, f)
    
#20x test preds
with open(f'{PRED_TRAIN_PATH}{MODEL_NAME}_20folds_test_cv{avg_error*1000:0>4.0f}_std{avg_std*1000:0>4.0f}.pkl', 'wb') as f:
    pickle.dump(avg_test_pred_20, f)

#20x5 models
# with open(f'{PRED_TRAIN_PATH}{MODEL_NAME}_20folds_models_cv{avg_error*1000:0>4.0f}_std{avg_std*1000:0>4.0f}.pkl', 'wb') as f:
#     pickle.dump(models_all, f)
# Out:
# Wall time: 26 ms

# %%
# %%time
sub_df = pd.read_csv(f'{DATA_PATH}sample_submission.csv')#, usecols = ['ID']
model_to_submit = pd.DataFrame({ 'ID': sub_df['ID'].values,
                            'target': avg_pred_test_list_lgb})
model_to_submit.to_csv(f'{PRED_TEST_PATH}{MODEL_NAME}_20folds_test_averaged_cv{avg_error*1000:0>4.0f}_std{avg_std*1000:0>4.0f}.csv',
                       index=False)
# Out:
# Wall time: 226 ms
